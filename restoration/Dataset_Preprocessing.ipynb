# %% [markdown]
# # OCR Preprocessing Pipeline for Renaissance Documents
#
# This notebook randomly samples pages from a set of PDF documents, converts them to images, and applies a standard OCR preprocessing pipeline:
# - Grayscale conversion
# - Noise removal (median filter)
# - Binarization (Otsu’s threshold)
# - Deskewing
#
# You'll end up with clean, black-and-white PNG files ready for OCR.

# %% [markdown]
# ### 1. Install Dependencies
#
# Run the following cell to install necessary packages (requires Poppler installed on your system):

# %%
# %pip install pdf2image opencv-python numpy gdown ipywidgets matplotlib opencv-python-headless

# %% [markdown]
# ### 2. Imports and Configuration
#
# Adjust the paths below to point to your PDF directory and desired output folder.

# %%
import os
import random
from pdf2image import convert_from_path, pdfinfo_from_path
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image

# Disable PIL bomb check
Image.MAX_IMAGE_PIXELS = None

# Configuration
pdf_dir = '/data/pdfs'
pdf_samples_dir = '/data/pdf_samples'
png_dir = '/data/pngs'
processed_dir = '/data/processed_data'
processed_resized_dir = '/data/processed_resized'
POPPLER_PATH = 'C:/Users/katej/OneDrive/Documents/Downloads/Release-24.08.0-0/poppler-24.08.0/Library/bin/'
# Update to your own path

os.makedirs(processed_dir, exist_ok=True)

# Set DPI for conversion
DPI = 300

# %% [markdown]
# #### Download DataSets from Google Drive Folder

# %%
folder_id = "1B_dM138pLrQGxRqUn1wcFO2MEotGWr7h"
gdown_command = f"gdown --folder {folder_id} -O {pdf_dir}"
print('Running:', gdown_command)
# !{gdown_command}
# Out:
# Running: gdown --folder 1B_dM138pLrQGxRqUn1wcFO2MEotGWr7h -O /data/pdfs
# ^C
# Retrieving folder contents
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1E7bnev2iGtg6AyGc1s8VNhLUUntdv3er
# To: c:\data\pdfs\Ayala, Lorenzo de. Valladolid 1603.pdf
#
#   0%|          | 0.00/6.42M [00:00<?, ?B/s]
#  16%|█▋        | 1.05M/6.42M [00:00<00:00, 10.4MB/s]
#  41%|████      | 2.62M/6.42M [00:00<00:00, 11.0MB/s]
#  65%|██████▌   | 4.19M/6.42M [00:00<00:00, 11.5MB/s]
#  90%|████████▉ | 5.77M/6.42M [00:00<00:00, 11.5MB/s]
# 100%|██████████| 6.42M/6.42M [00:00<00:00, 11.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1L-hYw-dH52EQm5Di2ZhgPWEuscL3cF7f
# To: c:\data\pdfs\Burgos, Juan de. Valladolid 1500.pdf
#
#   0%|          | 0.00/52.7M [00:00<?, ?B/s]
#   2%|▏         | 1.05M/52.7M [00:00<00:05, 9.35MB/s]
#   4%|▍         | 2.10M/52.7M [00:00<00:07, 6.95MB/s]
#   6%|▌         | 3.15M/52.7M [00:00<00:07, 6.42MB/s]
#   8%|▊         | 4.19M/52.7M [00:00<00:07, 6.19MB/s]
#  10%|▉         | 5.24M/52.7M [00:00<00:07, 6.68MB/s]
#  12%|█▏        | 6.29M/52.7M [00:00<00:06, 7.28MB/s]
#  14%|█▍        | 7.34M/52.7M [00:01<00:05, 7.82MB/s]
#  17%|█▋        | 8.91M/52.7M [00:01<00:04, 8.97MB/s]
B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oqOE-13uE6w2u6u-r-_9K6VRCRrrRGst
# To: c:\data\pdfs\Cerda - Estados mujeres OG BW.pdf
#
#   0%|          | 0.00/58.9M [00:00<?, ?B/s]
#   2%|▏         | 1.05M/58.9M [00:00<00:06, 8.88MB/s]
#   4%|▍         | 2.62M/58.9M [00:00<00:05, 10.7MB/s]
#   7%|▋         | 4.19M/58.9M [00:00<00:04, 11.0MB/s]
#  10%|▉         | 5.77M/58.9M [00:00<00:04, 11.4MB/s]
#  12%|█▏        | 7.34M/58.9M [00:00<00:04, 11.6MB/s]
#  15%|█▌        | 8.91M/58.9M [00:00<00:04, 11.7MB/s]
#  18%|█▊        | 10.5M/58.9M [00:00<00:04, 11.7MB/s]
#  20%|██        | 12.1M/58.9M [00:01<00:03, 11.8MB/s]
#  23%|██▎       | 13.6M/58.9M [00:01<00:03, 11.8MB/s]
#  26%|██▌       | 15.2M/58.9M [00:01<00:03, 11.8MB/s]
#  28%|██▊       | 16.8M/58.9M [00:01<00:03, 11.8MB/s]
#  31%|███       | 18.4M/58.9M [00:01<00:03, 11.8MB/s]
#  34%|███▍      | 19.9M/58.9M [00:01<00:03, 11.7MB/s]
#  36%|███▋      | 21.5M/58.9M [00:01<00:03, 11.8MB/s]
#  39%|███▉      | 23.1M/58.9M [00:01<00:03, 11.8MB/s]
#  42%|████▏     | 24.6M/58.9M [00:02<00:02, 11.8MB/s]
#  44%|████▍     | 26.2M/58.9M [00:02<00:02, 11.8MB/s]
#  47%|████▋     | 27.8M/58.9M [00:02<00:02, 11.9MB/s]
#  50%|████▉     | 29.4M/58.9M [00:02<00:02, 11.9MB/s]
#  52%|█████▏    | 30.9M/58.9M [00:02<00:02, 11.8MB/s]
#  55%|█████▌    | 32.5M/58.9M [00:02<00:02, 11.8MB/s]
#  58%|█████▊    | 34.1M/58.9M [00:02<00:02, 11.8MB/s]
#  60%|██████    | 35.7M/58.9M [00:03<00:02, 11.2MB/s]
#  63%|██████▎   | 37.2M/58.9M [00:03<00:02, 10.2MB/s]
#  65%|██████▍   | 38.3M/58.9M [00:03<00:02, 10.1MB/s]
#  68%|██████▊   | 39.8M/58.9M [00:03<00:01, 10.6MB/s]
#  70%|███████   | 41.4M/58.9M [00:03<00:01, 10.9MB/s]
#  73%|███████▎  | 43.0M/58.9M [00:03<00:01, 11.2MB/s]
#  76%|███████▌  | 44.6M/58.9M [00:03<00:01, 11.4MB/s]
#  78%|███████▊  | 46.1M/58.9M [00:04<00:01, 11.5MB/s]
#  81%|████████  | 47.7M/58.9M [00:04<00:00, 11.6MB/s]
#  84%|████████▎ | 49.3M/58.9M [00:04<00:00, 11.7MB/s]
#  86%|████████▋ | 50.9M/58.9M [00:04<00:00, 11.7MB/s]
#  89%|████████▉ | 52.4M/58.9M [00:04<00:00, 11.7MB/s]
#  92%|█████████▏| 54.0M/58.9M [00:04<00:00, 11.8MB/s]
#  94%|█████████▍| 55.6M/58.9M [00:04<00:00, 11.8MB/s]
#  97%|█████████▋| 57.1M/58.9M [00:04<00:00, 11.6MB/s]
# 100%|█████████▉| 58.7M/58.9M [00:05<00:00, 11.9MB/s]
# 100%|██████████| 58.9M/58.9M [00:05<00:00, 11.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=
# Processing file 1L-hYw-dH52EQm5Di2ZhgPWEuscL3cF7f Burgos, Juan de. Valladolid 1500.pdf
# Processing file 17uxQuvlHBHSAWtb0UCKmGKIhg0WZPXfm Cansoles, Fernando. Mallorca 1541.pdf
# Processing file 1oqOE-13uE6w2u6u-r-_9K6VRCRrrRGst Cerda - Estados mujeres OG BW.pdf
# Processing file 1YkN5ZWdr6veG1JPNRrvKfK0ijFyNlkST Guevara - Reloj de Principes OG.pdf

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from pdf2image import convert_from_path, pdfinfo_from_path
from ipywidgets import (
    widgets, interact, interactive_output, VBox, HBox,
    IntSlider, FloatSlider, Checkbox, Button, Output
)
import os

# --- Global state ---
POPPLER_PATH = 'C:/Users/katej/OneDrive/Documents/Downloads/Release-24.08.0-0/poppler-24.08.0/Library/bin/'
latest_data = {"image": None, "page": None, "pdf_path": None, "dpi": 300}

# --- PDF & processing ---
def load_pdf_page(pdf_path, page_num=1, dpi=300):
    img = convert_from_path(
        pdf_path,
        dpi=dpi,
        first_page=page_num,
        last_page=page_num,
        poppler_path=POPPLER_PATH
    )[0]
    return np.array(img)[:, :, ::-1]  # PIL RGB to OpenCV BGR

def apply_pipeline(
    img_bgr,
    min_area=50,
    clahe_clip=3.0,
    blur_kernel=55,
    denoise_h=10,
    do_denoise=True,
    do_bg_removal=True,
    do_contrast=True,
    do_binarize=True,
    do_close=True,
    do_filter=True
):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

    if do_denoise:
        gray = cv2.fastNlMeansDenoising(gray, None, h=denoise_h, templateWindowSize=7, searchWindowSize=21)

    if do_bg_removal:
        blur_kernel = max(3, blur_kernel | 1)  # force odd
        bg = cv2.medianBlur(gray, blur_kernel)
        gray = cv2.divide(gray, bg, scale=255)

    if do_contrast:
        clahe = cv2.createCLAHE(clipLimit=clahe_clip, tileGridSize=(8, 8))
        enhanced = clahe.apply(gray)
        lo, hi = np.percentile(enhanced, [2, 98])
        gray = np.clip((enhanced - lo) * (255.0 / (hi - lo)), 0, 255).astype(np.uint8)

    if do_binarize:
        _, bw_inv = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        bw = cv2.bitwise_not(bw_inv)
    else:
        bw = gray.copy()

    if do_close:
        bw = cv2.morphologyEx(bw, cv2.MORPH_CLOSE, np.ones((2, 2), np.uint8))

    if do_filter:
        num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(bw, connectivity=8)
        cleaned = np.zeros_like(bw)
        for i in range(1, num_labels):
            if stats[i, cv2.CC_STAT_AREA] >= min_area:
                cleaned[labels == i] = 255
        bw = cleaned

    return bw

# --- Widgets ---
pdf_path_widget = widgets.Text(
    value='data\pdfs\Padilla - 2 Noble perfecto_Extract.pdf',
    description='PDF Path:',
    layout=widgets.Layout(width='600px')
)
page_widget = IntSlider(min=1, max=10, step=1, value=1, description='Page')

min_area_widget = IntSlider(min=10, max=500, step=10, value=50, description='Min Area')
clahe_clip_widget = FloatSlider(min=1.0, max=10.0, step=0.5, value=3.0, description='CLAHE Clip')
blur_kernel_widget = IntSlider(min=3, max=101, step=2, value=55, description='Blur Kernel')
denoise_h_widget = IntSlider(min=0, max=30, step=1, value=10, description='Denoise H')

toggles = {
    "do_denoise": Checkbox(value=True, description="Denoise"),
    "do_bg_removal": Checkbox(value=True, description="Background Removal"),
    "do_contrast": Checkbox(value=True, description="CLAHE + Stretch"),
    "do_binarize": Checkbox(value=True, description="Binarize"),
    "do_close": Checkbox(value=True, description="Close Gaps"),
    "do_filter": Checkbox(value=True, description="Filter Components"),
}

# --- Update function ---
def update(pdf_path, page, min_area, clahe_clip, blur_kernel, denoise_h,
           do_denoise, do_bg_removal, do_contrast,
           do_binarize, do_close, do_filter):

    try:
        img_bgr = load_pdf_page(pdf_path, page, dpi=latest_data["dpi"])
    except Exception as e:
        print(f"Error loading PDF page: {e}")
        return

    result = apply_pipeline(
        img_bgr,
        min_area=min_area,
        clahe_clip=clahe_clip,
        blur_kernel=blur_kernel,
        denoise_h=denoise_h,
        do_denoise=do_denoise,
        do_bg_removal=do_bg_removal,
        do_contrast=do_contrast,
        do_binarize=do_binarize,
        do_close=do_close,
        do_filter=do_filter
    )

    # Store for saving
    latest_data["image"] = result
    latest_data["page"] = page
    latest_data["pdf_path"] = pdf_path

    # Display
    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
    plt.title("Original")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(result, cmap='gray')
    plt.title("Processed")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# --- Save logic ---
save_button = Button(description="Save current page", button_style='success')
save_all_checkbox = Checkbox(value=False, description="Save ALL pages")
save_output = Output()

def save_processed_image(img, out_path):
    Path(os.path.dirname(out_path)).mkdir(exist_ok=True)
    cv2.imwrite(out_path, img)

def on_save_clicked(b):
    with save_output:
        save_output.clear_output()
        if save_all_checkbox.value:
            print("Saving all pages...")
            try:
                info = pdfinfo_from_path(latest_data["pdf_path"], poppler_path=POPPLER_PATH)
                total_pages = info["Pages"]
                for pg in range(1, total_pages + 1):
                    img_bgr = load_pdf_page(latest_data["pdf_path"], page_num=pg, dpi=latest_data["dpi"])
                    result = apply_pipeline(
                        img_bgr,
                        min_area=min_area_widget.value,
                        clahe_clip=clahe_clip_widget.value,
                        blur_kernel=blur_kernel_widget.value,
                        denoise_h=denoise_h_widget.value,
                        do_denoise=toggles["do_denoise"].value,
                        do_bg_removal=toggles["do_bg_removal"].value,
                        do_contrast=toggles["do_contrast"].value,
                        do_binarize=toggles["do_binarize"].value,
                        do_close=toggles["do_close"].value,
                        do_filter=toggles["do_filter"].value,
                    )
                    out_path = os.path.join("output", f"{Path(latest_data['pdf_path']).stem}_p{pg:03d}.png")
                    save_processed_image(result, out_path)
                print(f"Saved {total_pages} pages to /output/")
            except Exception as e:
                print(f"Error saving pages: {e}")
        else:
            img = latest_data["image"]
            page_num = latest_data["page"]
            if img is None:
                print("No processed image to save yet.")
                return
            out_path = os.path.join("output", f"{Path(latest_data['pdf_path']).stem}_p{page_num:03d}.png")
            save_processed_image(img, out_path)
            print(f"Saved current page to {out_path}")

save_button.on_click(on_save_clicked)

# --- UI display ---
ui = VBox([
    pdf_path_widget,
    page_widget,
    min_area_widget,
    clahe_clip_widget,
    blur_kernel_widget,
    denoise_h_widget,
    VBox(list(toggles.values())),
    HBox([save_button, save_all_checkbox]),
    save_output
])

out = interactive_output(update, {
    "pdf_path": pdf_path_widget,
    "page": page_widget,
    "min_area": min_area_widget,
    "clahe_clip": clahe_clip_widget,
    "blur_kernel": blur_kernel_widget,
    "denoise_h": denoise_h_widget,
    **toggles
})

display(ui, out)
# Out:
# VBox(children=(Text(value='data\\pdfs\\Padilla - 2 Noble perfecto_Extract.pdf', description='PDF Path:', layou…
# Output()

# %% [markdown]
# Example of Data Extraction. Ensure Nobleza Virtuosa and Noble Perfecto are preprocessed and saved in their respective folders.

# %%
# Define paths for image folders and outputs
image_folders = {
    "Nobleza Virtuosa": {
        "pdf": Path("data/pdfs/Padilla - Nobleza virtuosa_testExtract.pdf"),
        "processed": Path("data/processed_data_virtuosa"),
        "bounding_boxes": Path("output/craft/boxes_virtuosa"),
        "bounding_boxes_sorted": Path("output/craft/boxes_sorted_virtuosa"),
        "gt_docx": Path("data/transcriptions/Padilla - 1 Nobleza virtuosa_testTranscription.docx"),
        "text_file": Path("data/transcriptions/NoblezaVirtuosa_all_text.txt"),
        "split_text_output": Path("data/split_data_nobleza/textSplitted_NoblezaVirtuosa"),
    },

    "Noble Perfecto": {
        "pdf": Path("data/pdfs/Padilla - 2 Noble perfecto_Extract.pdf"),
        "processed": Path("data/processed_data_perfecto"),
        "output": Path("output/craft/boxes_perfecto"),
        "bounding_boxes": Path("output/craft/boxes_perfecto"),
        "bounding_boxes_sorted": Path("output/craft/boxes_sorted_perfecto"),
        "gt_docx": Path("data/transcriptions/Padilla - 2 Noble perfecto_Transcription.docx"),
        "text_file": Path("data/transcriptions/NoblePerfecto_all_text.txt"),
        "split_text_output": Path("data/split_data_perfecto/textSplitted_NoblePerfecto")
    }
}

# %% [markdown]
# Download the PDFs

# %%
PDF_DIR = Path("data/pdfs")
FOLDER_ID ='1wMSs07lgET5sjA-alaoZ3CcNF_cEpRE2'

gdown_command = f"gdown --folder https://drive.google.com/drive/folders/{FOLDER_ID} -O {PDF_DIR}"
print('Running:', gdown_command)
# !{gdown_command}
# Out:
# Running: gdown --folder https://drive.google.com/drive/folders/1wMSs07lgET5sjA-alaoZ3CcNF_cEpRE2 -O data\pdfs
# Processing file 133Qubpcdwqa-dCZ0luuT31kT89FxOkHP Padilla - 2 Noble perfecto_Extract.pdf
# Processing file 1BtDs1-3xZNi6aB-V3dXmHSiZIVCaeUuu Padilla - Nobleza virtuosa_testExtract.pdf
# Retrieving folder contents
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=133Qubpcdwqa-dCZ0luuT31kT89FxOkHP
# To: c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\data\pdfs\Padilla - 2 Noble perfecto_Extract.pdf
#
#   0%|          | 0.00/3.95M [00:00<?, ?B/s]
#  40%|███▉      | 1.57M/3.95M [00:00<00:00, 11.2MB/s]
#  80%|███████▉  | 3.15M/3.95M [00:00<00:00, 11.6MB/s]
# 100%|██████████| 3.95M/3.95M [00:00<00:00, 11.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BtDs1-3xZNi6aB-V3dXmHSiZIVCaeUuu
# To: c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\data\pdfs\Padilla - Nobleza virtuosa_testExtract.pdf
#
#   0%|          | 0.00/2.58M [00:00<?, ?B/s]
#  41%|████      | 1.05M/2.58M [00:00<00:00, 8.73MB/s]
# 100%|██████████| 2.58M/2.58M [00:00<00:00, 10.5MB/s]
# 100%|██████████| 2.58M/2.58M [00:00<00:00, 10.3MB/s]
# Download completed

# %% [markdown]
# Once they are preprocessed and saved. split them into individual pages.

# %%
from utils import split_and_save_image
import os

processed_dir = image_folders["Nobleza Virtuosa"]["processed"]
image_files = sorted([f for f in os.listdir(processed_dir) if f.lower().endswith('.png')])

last_image_number = 1

for fname in image_files:
    image_path = os.path.join(processed_dir, fname)
    last_image_number = split_and_save_image(
        image_path=image_path,
        output_folder=processed_dir,
        last_image_number=last_image_number
    )

processed_dir = image_folders["Noble Perfecto"]["processed"]
image_files = sorted([f for f in os.listdir(processed_dir) if f.lower().endswith('.png')])

last_image_number = 1

for fname in image_files:
    image_path = os.path.join(processed_dir, fname)
    last_image_number = split_and_save_image(
        image_path=image_path,
        output_folder=processed_dir,
        last_image_number=last_image_number
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 import os
#       4 processed_dir = image_folders["Nobleza Virtuosa"]["processed"]
# ----> 5 image_files = sorted([f for f in os.listdir(processed_dir) if f.lower().endswith('.png')])
#       7 last_image_number = 1
#       9 for fname in image_files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data\\processed_data_virtuosa'

# %% [markdown]
# Text Detection with CRAFT (https://github.com/clovaai/CRAFT-pytorch)

# %%
# !git clone https://github.com/kaoreill/CRAFT_Model.git

# %%
#It generally takes about ~3-4 mins
# !python CRAFT_Model/CRAFT/BoundBoxFunc/test.py --result_folder=image_folders["Noble Perfecto"]["bounding_boxes"]  --test_folder=image_folders["Noble Perfecto"]["processed"]  --trained_model="CRAFT_Model/CRAFT/BoundBoxFunc/weights/craft_mlt_25k.pth"
#It generally takes about ~3-4 mins
# !python CRAFT_Model/CRAFT/BoundBoxFunc/test.py --result_folder=image_folders["Nobleza Virtuosa"]["bounding_boxes"]  --test_folder=image_folders["Nobleza Virtuosa"]["processed"]  --trained_model="CRAFT_Model/CRAFT/BoundBoxFunc/weights/craft_mlt_25k.pth"

# %%
# !python CRAFT_Model/CRAFT/BoundBoxFunc/test.py --result_folder="output/craft/boxes"  --test_folder="data/processed_pages"  --trained_model="CRAFT_Model/CRAFT/BoundBoxFunc/weights/craft_mlt_25k.pth"
# Out:
# Loading weights from checkpoint (CRAFT_Model/CRAFT/BoundBoxFunc/weights/craft_mlt_25k.pth)
# Test image 1/32: data/processed_pages\page_001.png
# Test image 2/32: data/processed_pages\page_002.png
# Test image 3/32: data/processed_pages\page_003.png
# Test image 4/32: data/processed_pages\page_004.png
# Test image 5/32: data/processed_pages\page_005.png
# Test image 6/32: data/processed_pages\page_006.png
# Test image 7/32: data/processed_pages\page_007.png
# Test image 8/32: data/processed_pages\page_008.png
# Test image 9/32: data/processed_pages\page_009.png
# Test image 10/32: data/processed_pages\page_010.png
# Test image 11/32: data/processed_pages\page_011.png
# Test image 12/32: data/processed_pages\page_012.png
# Test image 13/32: data/processed_pages\page_013.png
# Test image 14/32: data/processed_pages\page_014.png
# Test image 15/32: data/processed_pages\page_015.png
# Test image 16/32: data/processed_pages\page_016.png
# Test image 17/32: data/processed_pages\page_017.png
# Traceback (most recent call last):
#   File "c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\CRAFT_Model\CRAFT\BoundBoxFunc\test.py", line 146, in <module>
#     bboxes, polys, score_text = test_net(net, image, args.text_threshold, args.link_threshold, args.low_text, args.cuda, args.poly, refine_net)
#   File "c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\CRAFT_Model\CRAFT\BoundBoxFunc\test.py", line 84, in test_net
#     y, feature = net(x)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\CRAFT_Model\CRAFT\BoundBoxFunc\craft.py", line 60, in forward
#     sources = self.basenet(x)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\CRAFT_Model\CRAFT\BoundBoxFunc\basenet\vgg16_bn.py", line 61, in forward
#     h = self.slice1(X)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\container.py", line 141, in forward
#     input = module(input)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\conv.py", line 446, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "c:\Users\katej\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\conv.py", line 442, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:76] data. DefaultCPUAllocator: not enough memory: you tried to allocate 293601280 bytes.

# %% [markdown]
# Sort Bounding Boxes

# %%
from utils import sort_bounding_boxes

sort_bounding_boxes(input_dir=image_folders["Nobleza Virtuosa"]["bounding_boxes"], output_dir=image_folders["Nobleza Virtuosa"]["bounding_boxes_sorted"],)
sort_bounding_boxes(input_dir=image_folders["Noble Perfecto"]["bounding_boxes"], output_dir=image_folders["Noble Perfecto"]["bounding_boxes_sorted"],)

# %%
from utils import sort_bounding_boxes

sort_bounding_boxes(input_dir="output/craft/boxes", output_dir="output/craft/boxes_sorted")
# Out:
# Processing bounding boxes in: output\craft\boxes
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p001_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p002_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p003_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p004_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p005_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p006_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p007_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p008_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p009_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p010_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p011_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p012_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p013_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p014_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p015_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p016_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p017_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p018_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p019_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p020_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p021_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p022_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p023_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p024_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p025_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p026_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p027_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p028_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p029_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p030_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p031_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p032_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p033_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p034_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p035_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p036_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p037_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p038_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p039_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p040_sorted.txt
# Sorted boxes written: res_BorbÃ³n_ROTUNDA_p041_sorted.txt
# All bounding boxes sorted. Output in: output\craft\boxes_sorted

# %% [markdown]
# Extract Transcriptions

# %%
from utils import extract_ground_truth_for_dataset

extract_ground_truth_for_dataset(
    docx_file="data/transcriptions/Feijoo_ROMAN.docx",
    output_path="data/transcriptions/Feijoo_ROMAN_all_text.txt",
)
# Out:
# Ground truth text saved to data\transcriptions\Feijoo_ROMAN_all_text.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from utils import extract_ground_truth_for_dataset
# ----> 3 extract_ground_truth_for_dataset(
#       4     docx_file="data/transcriptions/Feijoo_ROMAN.docx",
#       5     output_path="data/transcriptions/Feijoo_ROMAN_all_text.txt",
#       6 )
#
# File c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\utils.py:343, in extract_ground_truth_for_dataset(docx_file, output_path)
#     333 print(f"Ground truth text saved to {output_path}")
#     334 """
#     335 Extracts word regions from images based on bounding box coordinates in .txt files.
#     336
#    (...)
#     341     box_format (str): File extension of box files (default is 'txt').
#     342 """
# --> 343 os.makedirs(output_folder, exist_ok=True)
#     345 image_paths = sorted(Path(image_folder).glob("*.png"))
#     346 for img_path in image_paths:
#
# NameError: name 'output_folder' is not defined

# %%
from utils import extract_ground_truth_for_dataset

extract_ground_truth_for_dataset(
    docx_file="data\transcriptions\Padilla_Nobleza_virtuosa_testTranscription.docx",
    output_path=image_folders["Nobleza Virtuosa"]["text_file"]
)
extract_ground_truth_for_dataset(
    docx_file=image_folders["Noble Perfecto"]["gt_docx"],
    output_path=image_folders["Noble Perfecto"]["text_file"]
)
# Out:
# .docx not found: data	ranscriptions\Padilla_Nobleza_virtuosa_testTranscription.docx
# .docx not found: data\transcriptions\Padilla - 2 Noble perfecto_Transcription.docx

# %%
from utils import extract_ground_truth_for_dataset

extract_ground_truth_for_dataset(
    docx_file="data/transcriptions/Padilla_Nobleza_virtuosa_testTranscription.docx",
    output_path="data/transcriptions/NoblezaVirtuosa_all_text.txt"
)
# Out:
# Ground truth text saved to data\transcriptions\NoblezaVirtuosa_all_text.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 from utils import extract_ground_truth_for_dataset
# ----> 3 extract_ground_truth_for_dataset(
#       4     docx_file="data/transcriptions/Padilla_Nobleza_virtuosa_testTranscription.docx",
#       5     output_path="data/transcriptions/NoblezaVirtuosa_all_text.txt"
#       6 )
#
# File c:\Users\katej\OneDrive\Documents\GitHub\RenAIssance_fork\RenAIssance_CRNN_OCR_Kate_OReilly_orig\utils.py:343, in extract_ground_truth_for_dataset(docx_file, output_path)
#     333 print(f"Ground truth text saved to {output_path}")
#     334 """
#     335 Extracts word regions from images based on bounding box coordinates in .txt files.
#     336
#    (...)
#     341     box_format (str): File extension of box files (default is 'txt').
#     342 """
# --> 343 os.makedirs(output_folder, exist_ok=True)
#     345 image_paths = sorted(Path(image_folder).glob("*.png"))
#     346 for img_path in image_paths:
#
# NameError: name 'output_folder' is not defined

# %% [markdown]
# Split Transcription By Page

# %%
from utils import process_textfiles
import os

for name, paths in image_folders.items():
    textfile = paths["text_file"]
    sorted_BoundBox_folder = paths["bounding_boxes_sorted"]
    output_folder = paths["split_text_output"]
    os.makedirs(output_folder, exist_ok=True)
    print(f"Splitting text for {name}...")
    process_textfiles(textfile, sorted_BoundBox_folder, output_folder)
    print(f"Text splitting complete for {name}! Output: {output_folder}")

# %%
from utils import process_textfiles
import os

textfile = "data/data_3/borbon.txt"
sorted_BoundBox_folder = "output/craft/boxes_sorted"
output_folder = "data/data_3/split_text_output"
os.makedirs(output_folder, exist_ok=True)
print(f"Splitting text for...")
process_textfiles(textfile, sorted_BoundBox_folder, output_folder)
print(f"Text splitting complete for! Output: {output_folder}")
# Out:
# Splitting text for...
# Found 0 text pages and 0 bbox files.
# Text splitting complete. Output written to: data\data_3\split_text_output
# Text splitting complete for! Output: data/data_3/split_text_output

# %% [markdown]
# Extract and Save Labelled Boxes

# %%
from utils import apply_extraction_to_folder_for_train

for name, paths in image_folders.items():
    apply_extraction_to_folder_for_train(
        image_folder=paths["processed"],
        bounding_box_folder=paths["bounding_boxes_sorted"],
        text_folder=paths["split_text_output"],
        output_folder="content/train_data/",
    )

# %%
from utils import apply_extraction_to_folder_for_test

for name, paths in image_folders.items():
    apply_extraction_to_folder_for_test(
        image_folder=paths["processed"],
        bounding_box_folder=paths["bounding_boxes_sorted"],
        output_folder="content/test_data/",
    )

# %% [markdown]
# Pad and Resize Images

# %%
from utils import pad_and_resize_images

pad_and_resize_images("content/train_data")
pad_and_resize_images("content/test_data")

# %%
from utils import pad_and_resize_images
pad_and_resize_images("data/data_3/")
# Out:
# Processed: data/data_3/&c..png
# Processed: data/data_3/1.png
# Processed: data/data_3/10°.png
# Processed: data/data_3/10Â°.png
# Processed: data/data_3/12.png
# Processed: data/data_3/12Â°.png
# Processed: data/data_3/13°.png
# Processed: data/data_3/13Â°.png
# Processed: data/data_3/14.png
# Processed: data/data_3/14Â°.png
# Processed: data/data_3/15°.png
# Processed: data/data_3/15Â°.png
# Processed: data/data_3/1786. (2).png
# Processed: data/data_3/1786..png
# Processed: data/data_3/17°.png
# Processed: data/data_3/17Â°.png
# Processed: data/data_3/18°.png
# Processed: data/data_3/18Â°.png
# Processed: data/data_3/19°.png
# Processed: data/data_3/19Â°.png
# Processed: data/data_3/1as.png
# Processed: data/data_3/1Â°.png
# Processed: data/data_3/2.png
# Processed: data/data_3/20°.png
# Processed: data/data_3/20Â°.png
# Processed: data/data_3/21°.png
# Processed: data/data_3/21Â°.png
# Processed: data/data_3/22°.png
# Processed: data/data_3/22Â°.png
# Processed: data/data_3/23°.png
# Processed: data/data_3/23Â°.png
# Processed: data/data_3/24°.png
# Processed: data/data_3/24Â°.png
# Processed: data/data_3/26°.png
# Processed: data/data_3/26Â°.png
# Processed: data/data_3/28°.png
# Processed: data/data_3/28Â°.png
# Processed: data/data_3/29°.png
# Processed: data/data_3/29Â°.png
# Processed: data/data_3/2Â°.png
# Processed: data/data_3/30°.png
# Processed: data/data_3/30Â°.png
# Processed: data/data_3/33°.png
# Processed: data/data_3/33Â°.png
# Processed: data/data_3/3°.png
# Processed: data/data_3/3Â°.png
# Processed: data/data_3/4.png
# Processed: data/data_3/4Â°.png
# Processed: data/data_3/5 (2).png
# Processed: data/data_3/5 (3).png
# Processed: data/data_3/5.png
# Processed: data/data_3/5Â°.png
# Processed: data/data_3/8°.png
# Processed: data/data_3/8Â°.png
# Processed: data/data_3/9°.png
# Processed: data/data_3/9Â°.png
# Processed: data/data_3/A (2).png
# Processed: data/data_3/a (3).png
# Processed: data/data_3/A (4).png
# Processed: data/data_3/a.png
# Processed: data/data_3/abiertamente (2).png
# Processed: data/data_3/abiertamente.png
# Processed: data/data_3/Abogado (2).png
# Processed: data/data_3/Abogado.png
# Processed: data/data_3/abraza (2).png
# Processed: data/data_3/abraza, (2).png
# Processed: data/data_3/abraza,.png
# Processed: data/data_3/abraza.png
# Processed: data/data_3/absolutamente (2).png
# Processed: data/data_3/absolutamente.png
# Processed: data/data_3/abstractas, (2).png
# Processed: data/data_3/abstractas,.png
# Processed: data/data_3/abstractas. (2).png
# Processed: data/data_3/abstractas..png
# Processed: data/data_3/abstractas; (2).png
# Processed: data/data_3/abstractas;.png
# Processed: data/data_3/abultado. (2).png
# Processed: data/data_3/abultado..png
# Processed: data/data_3/abuso (2).png
# Processed: data/data_3/abuso.png
# Processed: data/data_3/acabamos (2).png
# Processed: data/data_3/acabamos.png
# Processed: data/data_3/acabamos_1.png
# Processed: data/data_3/Academias, (2).png
# Processed: data/data_3/Academias,.png
# Processed: data/data_3/Acaso (2).png
# Processed: data/data_3/acaso (3).png
# Processed: data/data_3/acaso.png
# Processed: data/data_3/acaudillaba (2).png
# Processed: data/data_3/acaudillaba.png
# Processed: data/data_3/acciones, (2).png
# Processed: data/data_3/acciones,.png
# Processed: data/data_3/acomodadas, (2).png
# Processed: data/data_3/acomodadas,.png
# Processed: data/data_3/acompaÃ±ar (2).png
# Processed: data/data_3/acompaÃ±ar.png
# Processed: data/data_3/acostumbradas (2).png
# Processed: data/data_3/acostumbradas.png
# Processed: data/data_3/acostumbrado, (2).png
# Processed: data/data_3/acostumbrado,.png
# Processed: data/data_3/acreditadas (2).png
# Processed: data/data_3/acreditadas.png
# Processed: data/data_3/acreditado (2).png
# Processed: data/data_3/acreditado.png
# Processed: data/data_3/acreditado_1.png
# Processed: data/data_3/acreditan (2).png
# Processed: data/data_3/acreditan.png
# Processed: data/data_3/acreditar, (2).png
# Processed: data/data_3/acreditar,.png
# Processed: data/data_3/Actualmente (2).png
# Processed: data/data_3/Actualmente.png
# Processed: data/data_3/acuerdo (2).png
# Processed: data/data_3/acuerdo.png
# Processed: data/data_3/acumular (2).png
# Processed: data/data_3/acumular.png
# Processed: data/data_3/Adam,.png
# Processed: data/data_3/Adam,_1.png
# Processed: data/data_3/adelantar, (2).png
# Processed: data/data_3/adelantar,.png
# Processed: data/data_3/ademÃ¡s (2).png
# Processed: data/data_3/ademÃ¡s.png
# Processed: data/data_3/administrar (2).png
# Processed: data/data_3/administrar.png
# Processed: data/data_3/admirarlos, (2).png
# Processed: data/data_3/admirarlos,.png
# Processed: data/data_3/admision.png
# Processed: data/data_3/admisiÃ³n,.png
# Processed: data/data_3/admisiÃ³n.png
# Processed: data/data_3/admisiÃ³n_2.png
# Processed: data/data_3/admisiÃ³n_4.png
# Processed: data/data_3/admisiÃ³n_5.png
# Processed: data/data_3/admite (2).png
# Processed: data/data_3/admite.png
# Processed: data/data_3/admitida.png
# Processed: data/data_3/admitidas (2).png
# Processed: data/data_3/admitidas. (2).png
# Processed: data/data_3/admitidas..png
# Processed: data/data_3/admitidas.png
# Processed: data/data_3/admitidas_1.png
# Processed: data/data_3/admitidas_2.png
# Processed: data/data_3/admitidas_3.png
# Processed: data/data_3/admitida_1.png
# Processed: data/data_3/admitido (2).png
# Processed: data/data_3/admitido.png
# Processed: data/data_3/admitido_1.png
# Processed: data/data_3/admitir (2).png
# Processed: data/data_3/admitir.png
# Processed: data/data_3/admitirlas (2).png
# Processed: data/data_3/admitirlas.png
# Processed: data/data_3/admitir_1.png
# Processed: data/data_3/admitir_2.png
# Processed: data/data_3/adorna (2).png
# Processed: data/data_3/adorna.png
# Processed: data/data_3/adornar (2).png
# Processed: data/data_3/adornar.png
# Processed: data/data_3/adorno (2).png
# Processed: data/data_3/adorno.png
# Processed: data/data_3/adquirir (2).png
# Processed: data/data_3/adquirir.png
# Processed: data/data_3/adquirirla, (2).png
# Processed: data/data_3/adquirirla,.png
# Processed: data/data_3/adquirir_1.png
# Processed: data/data_3/advierte (2).png
# Processed: data/data_3/advierte.png
# Processed: data/data_3/agena (2).png
# Processed: data/data_3/agena.png
# Processed: data/data_3/agradable.png
# Processed: data/data_3/agrado, (2).png
# Processed: data/data_3/agrado,.png
# Processed: data/data_3/agrega (2).png
# Processed: data/data_3/agrega.png
# Processed: data/data_3/agricultura, (2).png
# Processed: data/data_3/agricultura,.png
# Processed: data/data_3/ahora_3.png
# Processed: data/data_3/ahora_5.png
# Processed: data/data_3/al (2).png
# Processed: data/data_3/al.png
# Processed: data/data_3/algun.png
# Processed: data/data_3/alguna (2).png
# Processed: data/data_3/alguna, (2).png
# Processed: data/data_3/alguna,.png
# Processed: data/data_3/alguna.png
# Processed: data/data_3/algunas.png
# Processed: data/data_3/algunas_1.png
# Processed: data/data_3/algunas_2.png
# Processed: data/data_3/algunas_3.png
# Processed: data/data_3/algunas_4.png
# Processed: data/data_3/algunas_5.png
# Processed: data/data_3/alguna_1.png
# Processed: data/data_3/alguna_3.png
# Processed: data/data_3/alguno (2).png
# Processed: data/data_3/alguno.png
# Processed: data/data_3/algunos.png
# Processed: data/data_3/algÃºn.png
# Processed: data/data_3/algÃºn_1.png
# Processed: data/data_3/alhagueÃ±o. (2).png
# Processed: data/data_3/alhagueÃ±o..png
# Processed: data/data_3/alistados.png
# Processed: data/data_3/alistaron.png
# Processed: data/data_3/alistaron_1.png
# Processed: data/data_3/al_10.png
# Processed: data/data_3/al_11.png
# Processed: data/data_3/al_12.png
# Processed: data/data_3/al_13.png
# Processed: data/data_3/al_14.png
# Processed: data/data_3/al_15.png
# Processed: data/data_3/al_16.png
# Processed: data/data_3/al_17.png
# Processed: data/data_3/al_18.png
# Processed: data/data_3/al_20.png
# Processed: data/data_3/al_21.png
# Processed: data/data_3/al_22.png
# Processed: data/data_3/al_23.png
# Processed: data/data_3/al_24.png
# Processed: data/data_3/al_25.png
# Processed: data/data_3/al_26.png
# Processed: data/data_3/al_28.png
# Processed: data/data_3/al_29.png
# Processed: data/data_3/al_31.png
# Processed: data/data_3/al_32.png
# Processed: data/data_3/al_4.png
# Processed: data/data_3/al_6.png
# Processed: data/data_3/al_7.png
# Processed: data/data_3/al_8.png
# Processed: data/data_3/aman, (2).png
# Processed: data/data_3/aman,.png
# Processed: data/data_3/Amar (2).png
# Processed: data/data_3/Amar. (2).png
# Processed: data/data_3/Amar..png
# Processed: data/data_3/Amar.png
# Processed: data/data_3/ambas.png
# Processed: data/data_3/ambos, (2).png
# Processed: data/data_3/ambos,.png
# Processed: data/data_3/ambos.png
# Processed: data/data_3/ambos_2.png
# Processed: data/data_3/ambos_3.png
# Processed: data/data_3/amenaza (2).png
# Processed: data/data_3/amenaza.png
# Processed: data/data_3/amigas (2).png
# Processed: data/data_3/amigas.png
# Processed: data/data_3/amigos.png
# Processed: data/data_3/amor.png
# Processed: data/data_3/amor_2.png
# Processed: data/data_3/animar (2).png
# Processed: data/data_3/animar.png
# Processed: data/data_3/antes (2).png
# Processed: data/data_3/antes.png
# Processed: data/data_3/antes_1.png
# Processed: data/data_3/antes_2.png
# Processed: data/data_3/antes_3.png
# Processed: data/data_3/antigua (2).png
# Processed: data/data_3/antigua.png
# Processed: data/data_3/antiguos (2).png
# Processed: data/data_3/antiguos.png
# Processed: data/data_3/apariencia. (2).png
# Processed: data/data_3/apariencia..png
# Processed: data/data_3/aparte (2).png
# Processed: data/data_3/aparte.png
# Processed: data/data_3/aparten (2).png
# Processed: data/data_3/aparten.png
# Processed: data/data_3/apenas (2).png
# Processed: data/data_3/apenas.png
# Processed: data/data_3/Apetecen (2).png
# Processed: data/data_3/Apetecen.png
# Processed: data/data_3/aplausos, (2).png
# Processed: data/data_3/aplausos,.png
# Processed: data/data_3/aplica, (2).png
# Processed: data/data_3/aplica,.png
# Processed: data/data_3/aplicaciÃ³n.png
# Processed: data/data_3/aplicadas (2).png
# Processed: data/data_3/aplicadas.png
# Processed: data/data_3/aplicarlas (2).png
# Processed: data/data_3/aplicarlas.png
# Processed: data/data_3/apliquen (2).png
# Processed: data/data_3/apliquen.png
# Processed: data/data_3/apliquen_1.png
# Processed: data/data_3/Apologista (2).png
# Processed: data/data_3/Apologista.png
# Processed: data/data_3/aprecio.png
# Processed: data/data_3/aprecio_1.png
# Processed: data/data_3/aprender, (2).png
# Processed: data/data_3/aprender,.png
# Processed: data/data_3/aprobando (2).png
# Processed: data/data_3/aprobando.png
# Processed: data/data_3/aprueba, (2).png
# Processed: data/data_3/aprueba,.png
# Processed: data/data_3/aptitud.png
# Processed: data/data_3/aptitud_1.png
# Processed: data/data_3/aptitud_2.png
# Processed: data/data_3/aptitud_3.png
# Processed: data/data_3/aptitud_4.png
# Processed: data/data_3/aquel (2).png
# Processed: data/data_3/aquel.png
# Processed: data/data_3/aquella (2).png
# Processed: data/data_3/aquella (3).png
# Processed: data/data_3/aquellas (2).png
# Processed: data/data_3/aquellas, (2).png
# Processed: data/data_3/aquellas,.png
# Processed: data/data_3/aquellas.png
# Processed: data/data_3/aqui.png
# Processed: data/data_3/aquÃ©lla;.png
# Processed: data/data_3/aquÃ©llas..png
# Processed: data/data_3/aquÃ©llas.png
# Processed: data/data_3/aquÃ­_2.png
# Processed: data/data_3/arbitrios, (2).png
# Processed: data/data_3/arbitrios,.png
# Processed: data/data_3/Argel, (2).png
# Processed: data/data_3/Argel,.png
# Processed: data/data_3/argumento, (2).png
# Processed: data/data_3/argumento,.png
# Processed: data/data_3/arrastra (2).png
# Processed: data/data_3/arrastra.png
# Processed: data/data_3/arrastrar (2).png
# Processed: data/data_3/arrastrar.png
# Processed: data/data_3/arrastrar_1.png
# Processed: data/data_3/arriba (2).png
# Processed: data/data_3/arriba.png
# Processed: data/data_3/arrostrado (2).png
# Processed: data/data_3/arrostrado.png
# Processed: data/data_3/arruinan (2).png
# Processed: data/data_3/arruinan.png
# Processed: data/data_3/artes, (2).png
# Processed: data/data_3/artes,.png
# Processed: data/data_3/artes,_1.png
# Processed: data/data_3/artes,_2.png
# Processed: data/data_3/artes; (2).png
# Processed: data/data_3/artes;.png
# Processed: data/data_3/artesano, (2).png
# Processed: data/data_3/artesano,.png
# Processed: data/data_3/artesanos, (2).png
# Processed: data/data_3/artesanos,.png
# Processed: data/data_3/artifices.png
# Processed: data/data_3/artÃ­fices..png
# Processed: data/data_3/asaltos (2).png
# Processed: data/data_3/asaltos.png
# Processed: data/data_3/Asamblea, (2).png
# Processed: data/data_3/Asamblea,.png
# Processed: data/data_3/asesinatos, (2).png
# Processed: data/data_3/asesinatos,.png
# Processed: data/data_3/asi (2).png
# Processed: data/data_3/asi,.png
# Processed: data/data_3/Asirios (2).png
# Processed: data/data_3/Asirios.png
# Processed: data/data_3/asisten, (2).png
# Processed: data/data_3/asisten,.png
# Processed: data/data_3/aspirar.png
# Processed: data/data_3/asuntos (2).png
# Processed: data/data_3/asuntos, (2).png
# Processed: data/data_3/asuntos,.png
# Processed: data/data_3/asuntos.png
# Processed: data/data_3/asuntos_1.png
# Processed: data/data_3/asuntos_2.png
# Processed: data/data_3/asuntos_3.png
# Processed: data/data_3/asÃ­,.png
# Processed: data/data_3/AsÃ­_2.png
# Processed: data/data_3/atarearse (2).png
# Processed: data/data_3/atarearse.png
# Processed: data/data_3/atendidas. (2).png
# Processed: data/data_3/atendidas..png
# Processed: data/data_3/Atenienses, (2).png
# Processed: data/data_3/Atenienses,.png
# Processed: data/data_3/atentado, (2).png
# Processed: data/data_3/atentado,.png
# Processed: data/data_3/atiende (2).png
# Processed: data/data_3/atiende.png
# Processed: data/data_3/atraer (2).png
# Processed: data/data_3/atraer.png
# Processed: data/data_3/atravesÃ³ (2).png
# Processed: data/data_3/atravesÃ³.png
# Processed: data/data_3/atreven (2).png
# Processed: data/data_3/atribuyen (2).png
# Processed: data/data_3/atribuyen.png
# Processed: data/data_3/atribuyen_1.png
# Processed: data/data_3/au.png
# Processed: data/data_3/aumentar.png
# Processed: data/data_3/a_81.png
# Processed: data/data_3/a_83.png
# Processed: data/data_3/a_84.png
# Processed: data/data_3/a_86.png
# Processed: data/data_3/a_87.png
# Processed: data/data_3/a_88.png
# Processed: data/data_3/a_89.png
# Processed: data/data_3/a_9.png
# Processed: data/data_3/a_90.png
# Processed: data/data_3/a_91.png
# Processed: data/data_3/a_92.png
# Processed: data/data_3/a_95.png
# Processed: data/data_3/a_96.png
# Processed: data/data_3/a_97.png
# Processed: data/data_3/a_98.png
# Processed: data/data_3/aÃ±adira.png
# Processed: data/data_3/aÃ±adirÃ¡.png
# Processed: data/data_3/aÃ±os (2).png
# Processed: data/data_3/aÃ±os.png
# Processed: data/data_3/aÃºn_1.png
# Processed: data/data_3/Basta.png
# Processed: data/data_3/bastan (2).png
# Processed: data/data_3/bastan.png
# Processed: data/data_3/bastante.png
# Processed: data/data_3/bastante_1.png
# Processed: data/data_3/bastaran.png
# Processed: data/data_3/bastarle (2).png
# Processed: data/data_3/bastarle.png
# Processed: data/data_3/bastarÃ¡n.png
# Processed: data/data_3/Baste (2).png
# Processed: data/data_3/Baste.png
# Processed: data/data_3/Beatriz (2).png
# Processed: data/data_3/Beatriz.png
# Processed: data/data_3/bello.png
# Processed: data/data_3/beneficio.png
# Processed: data/data_3/bien.png
# Processed: data/data_3/bien_1.png
# Processed: data/data_3/bien_2.png
# Processed: data/data_3/bien_5.png
# Processed: data/data_3/bien_7.png
# Processed: data/data_3/bondad (2).png
# Processed: data/data_3/bondad.png
# Processed: data/data_3/Borbon (2).png
# Processed: data/data_3/Borbon.png
# Processed: data/data_3/borra (2).png
# Processed: data/data_3/borra.png
# Processed: data/data_3/Broglio, (2).png
# Processed: data/data_3/Broglio,.png
# Processed: data/data_3/brutos, (2).png
# Processed: data/data_3/brutos,.png
# Processed: data/data_3/buena (2).png
# Processed: data/data_3/buena.png
# Processed: data/data_3/buenas (2).png
# Processed: data/data_3/buenas.png
# Processed: data/data_3/buena_2.png
# Processed: data/data_3/buscarse. (2).png
# Processed: data/data_3/buscarse..png
# Processed: data/data_3/cabeza (2).png
# Processed: data/data_3/cabeza.png
# Processed: data/data_3/cada (2).png
# Processed: data/data_3/cada.png
# Processed: data/data_3/cadenas..png
# Processed: data/data_3/cadenas.png
# Processed: data/data_3/caida.png
# Processed: data/data_3/calcular (2).png
# Processed: data/data_3/calcular.png
# Processed: data/data_3/calidades (2).png
# Processed: data/data_3/calidades,.png
# Processed: data/data_3/calidades.png
# Processed: data/data_3/cambio (2).png
# Processed: data/data_3/cambio.png
# Processed: data/data_3/capaces.png
# Processed: data/data_3/capaces_1.png
# Processed: data/data_3/capaces_2.png
# Processed: data/data_3/capacidad (2).png
# Processed: data/data_3/capacidad.png
# Processed: data/data_3/capacidad_1.png
# Processed: data/data_3/capaz (2).png
# Processed: data/data_3/capaz.png
# Processed: data/data_3/capaz_1.png
# Processed: data/data_3/Capitan.png
# Processed: data/data_3/CapitÃ¡n.png
# Processed: data/data_3/caprichos, (2).png
# Processed: data/data_3/caprichos,.png
# Processed: data/data_3/caprichosas (2).png
# Processed: data/data_3/caprichosas.png
# Processed: data/data_3/caracter.png
# Processed: data/data_3/carecen (2).png
# Processed: data/data_3/carecen.png
# Processed: data/data_3/carecen_1.png
# Processed: data/data_3/cargos.png
# Processed: data/data_3/carrera.png
# Processed: data/data_3/carÃ¡cter,.png
# Processed: data/data_3/casa,.png
# Processed: data/data_3/casa.png
# Processed: data/data_3/casadas..png
# Processed: data/data_3/casadas.png
# Processed: data/data_3/casi (2).png
# Processed: data/data_3/casi.png
# Processed: data/data_3/casi_1.png
# Processed: data/data_3/casi_4.png
# Processed: data/data_3/casi_5.png
# Processed: data/data_3/casi_8.png
# Processed: data/data_3/caso (2).png
# Processed: data/data_3/caso, (2).png
# Processed: data/data_3/caso,.png
# Processed: data/data_3/caso.png
# Processed: data/data_3/casos (2).png
# Processed: data/data_3/casos, (2).png
# Processed: data/data_3/casos,.png
# Processed: data/data_3/casos.png
# Processed: data/data_3/caso_1.png
# Processed: data/data_3/caso_2.png
# Processed: data/data_3/Catalinas (2).png
# Processed: data/data_3/Catalinas.png
# Processed: data/data_3/catalogo.png
# Processed: data/data_3/catÃ¡logo.png
# Processed: data/data_3/catÃ¡logo_1.png
# Processed: data/data_3/caudal.png
# Processed: data/data_3/caudales, (2).png
# Processed: data/data_3/caudales,.png
# Processed: data/data_3/caudales..png
# Processed: data/data_3/causa (2).png
# Processed: data/data_3/causa, (2).png
# Processed: data/data_3/causa,.png
# Processed: data/data_3/causa,_2.png
# Processed: data/data_3/causa.png
# Processed: data/data_3/causar (2).png
# Processed: data/data_3/causar.png
# Processed: data/data_3/causaria.png
# Processed: data/data_3/causarÃ­a.png
# Processed: data/data_3/causas (2).png
# Processed: data/data_3/causas.png
# Processed: data/data_3/causa_2.png
# Processed: data/data_3/causa_3.png
# Processed: data/data_3/causa_4.png
# Processed: data/data_3/caÃ­da.png
# Processed: data/data_3/cerradas (2).png
# Processed: data/data_3/cerradas.png
# Processed: data/data_3/Cetro,.png
# Processed: data/data_3/Cibo, (2).png
# Processed: data/data_3/Cibo,.png
# Processed: data/data_3/ciencia (2).png
# Processed: data/data_3/ciencia; (2).png
# Processed: data/data_3/ciencia;.png
# Processed: data/data_3/ciencias, (2).png
# Processed: data/data_3/ciencias,.png
# Processed: data/data_3/ciencias,_2.png
# Processed: data/data_3/ciencias.png
# Processed: data/data_3/ciencias_1.png
# Processed: data/data_3/cierta (2).png
# Processed: data/data_3/cierta.png
# Processed: data/data_3/ciertas (2).png
# Processed: data/data_3/ciertas.png
# Processed: data/data_3/ciertas_2.png
# Processed: data/data_3/cierto! (2).png
# Processed: data/data_3/cierto!.png
# Processed: data/data_3/cierto,.png
# Processed: data/data_3/cierto.png
# Processed: data/data_3/cierto_2.png
# Processed: data/data_3/circunstancias,.png
# Processed: data/data_3/citar.png
# Processed: data/data_3/citar_1.png
# Processed: data/data_3/civilizasen (2).png
# Processed: data/data_3/civilizasen.png
# Processed: data/data_3/clama.png
# Processed: data/data_3/claro (2).png
# Processed: data/data_3/claro.png
# Processed: data/data_3/clase,.png
# Processed: data/data_3/clase.png
# Processed: data/data_3/cobardes,.png
# Processed: data/data_3/cobardes,_1.png
# Processed: data/data_3/cobardes.png
# Processed: data/data_3/coger (2).png
# Processed: data/data_3/coger.png
# Processed: data/data_3/Colegios (2).png
# Processed: data/data_3/Colegios.png
# Processed: data/data_3/colmo (2).png
# Processed: data/data_3/colmo.png
# Processed: data/data_3/comenzo.png
# Processed: data/data_3/comenzÃ³.png
# Processed: data/data_3/comerciante, (2).png
# Processed: data/data_3/comerciante,.png
# Processed: data/data_3/comercio,.png
# Processed: data/data_3/comercio,_1.png
# Processed: data/data_3/cometiÃ³ (2).png
# Processed: data/data_3/cometiÃ³.png
# Processed: data/data_3/como (2).png
# Processed: data/data_3/como (3).png
# Processed: data/data_3/como (4).png
# Processed: data/data_3/como.png
# Processed: data/data_3/como_1.png
# Processed: data/data_3/como_10.png
# Processed: data/data_3/como_12.png
# Processed: data/data_3/como_13.png
# Processed: data/data_3/como_14.png
# Processed: data/data_3/como_15.png
# Processed: data/data_3/como_16.png
# Processed: data/data_3/como_17.png
# Processed: data/data_3/como_18.png
# Processed: data/data_3/como_19.png
# Processed: data/data_3/como_2.png
# Processed: data/data_3/como_20.png
# Processed: data/data_3/como_21.png
# Processed: data/data_3/como_22.png
# Processed: data/data_3/como_23.png
# Processed: data/data_3/como_24.png
# Processed: data/data_3/como_26.png
# Processed: data/data_3/como_27.png
# Processed: data/data_3/como_29.png
# Processed: data/data_3/como_30.png
# Processed: data/data_3/como_33.png
# Processed: data/data_3/como_37.png
# Processed: data/data_3/como_39.png
# Processed: data/data_3/como_4.png
# Processed: data/data_3/como_42.png
# Processed: data/data_3/como_7.png
# Processed: data/data_3/como_8.png
# Processed: data/data_3/como_9.png
# Processed: data/data_3/compara (2).png
# Processed: data/data_3/compara.png
# Processed: data/data_3/comparaciÃ³n (2).png
# Processed: data/data_3/comparaciÃ³n.png
# Processed: data/data_3/comparada (2).png
# Processed: data/data_3/comparada.png
# Processed: data/data_3/compaÃ±era, (2).png
# Processed: data/data_3/compaÃ±era,.png
# Processed: data/data_3/compaÃ±Ã­a.png
# Processed: data/data_3/compaÃ±Ã­a_1.png
# Processed: data/data_3/competente (2).png
# Processed: data/data_3/competente.png
# Processed: data/data_3/complacencia (2).png
# Processed: data/data_3/complacencia.png
# Processed: data/data_3/complacencia_1.png
# Processed: data/data_3/complemento (2).png
# Processed: data/data_3/complemento.png
# Processed: data/data_3/compondremos (2).png
# Processed: data/data_3/compondremos.png
# Processed: data/data_3/componen (2).png
# Processed: data/data_3/componen.png
# Processed: data/data_3/compostura (2).png
# Processed: data/data_3/compostura.png
# Processed: data/data_3/comprehende (2).png
# Processed: data/data_3/comprehende.png
# Processed: data/data_3/comprende (2).png
# Processed: data/data_3/comprende.png
# Processed: data/data_3/comprender (2).png
# Processed: data/data_3/comprender.png
# Processed: data/data_3/comun (2).png
# Processed: data/data_3/comun (3).png
# Processed: data/data_3/comun.png
# Processed: data/data_3/comunes, (2).png
# Processed: data/data_3/comunes,.png
# Processed: data/data_3/comÃºn,_1.png
# Processed: data/data_3/comÃºn..png
# Processed: data/data_3/comÃºn.png
# Processed: data/data_3/comÃºn_1.png
# Processed: data/data_3/comÃºn_2.png
# Processed: data/data_3/con (2).png
# Processed: data/data_3/Con.png
# Processed: data/data_3/conceda (2).png
# Processed: data/data_3/conceda.png
# Processed: data/data_3/conceden (2).png
# Processed: data/data_3/conceder (2).png
# Processed: data/data_3/conceder.png
# Processed: data/data_3/concedida (2).png
# Processed: data/data_3/concedida.png
# Processed: data/data_3/concepto, (2).png
# Processed: data/data_3/concepto,.png
# Processed: data/data_3/concluido (2).png
# Processed: data/data_3/concluido.png
# Processed: data/data_3/Concluyamos, (2).png
# Processed: data/data_3/Concluyamos,.png
# Processed: data/data_3/concluye (2).png
# Processed: data/data_3/concluye.png
# Processed: data/data_3/concluyente (2).png
# Processed: data/data_3/concluyente.png
# Processed: data/data_3/concluyente_1.png
# Processed: data/data_3/concluyente_2.png
# Processed: data/data_3/concurren, (2).png
# Processed: data/data_3/concurren,.png
# Processed: data/data_3/concurrencia (2).png
# Processed: data/data_3/concurrencia.png
# Processed: data/data_3/concurrencia_2.png
# Processed: data/data_3/concurrir, (2).png
# Processed: data/data_3/concurrir,.png
# Processed: data/data_3/condesce.png
# Processed: data/data_3/conducta (2).png
# Processed: data/data_3/conducta.png
# Processed: data/data_3/confesaba (2).png
# Processed: data/data_3/confesaba.png
# Processed: data/data_3/confesar, (2).png
# Processed: data/data_3/confesar,.png
# Processed: data/data_3/confirma (2).png
# Processed: data/data_3/confirma.png
# Processed: data/data_3/conforme, (2).png
# Processed: data/data_3/conforme,.png
# Processed: data/data_3/conformes, (2).png
# Processed: data/data_3/conformes,.png
# Processed: data/data_3/conformes. (2).png
# Processed: data/data_3/conformes..png
# Processed: data/data_3/conocemos (2).png
# Processed: data/data_3/conocemos.png
# Processed: data/data_3/conocer (2).png
# Processed: data/data_3/conocer, (2).png
# Processed: data/data_3/conocer,.png
# Processed: data/data_3/conocer.png
# Processed: data/data_3/conocidos, (2).png
# Processed: data/data_3/conocidos,.png
# Processed: data/data_3/conociendo (2).png
# Processed: data/data_3/conociendo.png
# Processed: data/data_3/conociera (2).png
# Processed: data/data_3/conociera.png
# Processed: data/data_3/conquista (2).png
# Processed: data/data_3/conquista.png
# Processed: data/data_3/conseguÃ­a, (2).png
# Processed: data/data_3/conseguÃ­a,.png
# Processed: data/data_3/consejo (2).png
# Processed: data/data_3/consejo.png
# Processed: data/data_3/Consejos, (2).png
# Processed: data/data_3/Consejos,.png
# Processed: data/data_3/conserva.png
# Processed: data/data_3/considerar (2).png
# Processed: data/data_3/considerar.png
# Processed: data/data_3/consiga, (2).png
# Processed: data/data_3/consiga,.png
# Processed: data/data_3/consiguen (2).png
# Processed: data/data_3/consiguen.png
# Processed: data/data_3/consiste (2).png
# Processed: data/data_3/consiste.png
# Processed: data/data_3/consiste_1.png
# Processed: data/data_3/constancia.png
# Processed: data/data_3/constancia_1.png
# Processed: data/data_3/constante (2).png
# Processed: data/data_3/constante.png
# Processed: data/data_3/constante_1.png
# Processed: data/data_3/consÃºltense (2).png
# Processed: data/data_3/consÃºltense.png
# Processed: data/data_3/cont.png
# Processed: data/data_3/contentos.png
# Processed: data/data_3/continua (2).png
# Processed: data/data_3/continua.png
# Processed: data/data_3/continÃºa (2).png
# Processed: data/data_3/continÃºa.png
# Processed: data/data_3/continÃºan.png
# Processed: data/data_3/contra (2).png
# Processed: data/data_3/contra.png
# Processed: data/data_3/contradiccion!.png
# Processed: data/data_3/contraposiciÃ³n (2).png
# Processed: data/data_3/contraposiciÃ³n.png
# Processed: data/data_3/contraria (2).png
# Processed: data/data_3/contraria.png
# Processed: data/data_3/contrarios,.png
# Processed: data/data_3/contra_1.png
# Processed: data/data_3/contra_2.png
# Processed: data/data_3/contribuciÃ³n.png
# Processed: data/data_3/contribuyan (2).png
# Processed: data/data_3/contribuyan.png
# Processed: data/data_3/contribuye (2).png
# Processed: data/data_3/contribuye.png
# Processed: data/data_3/contribuyen (2).png
# Processed: data/data_3/contribuyen.png
# Processed: data/data_3/contribuyentes, (2).png
# Processed: data/data_3/contribuyentes,.png
# Processed: data/data_3/contÃ³ (2).png
# Processed: data/data_3/contÃ³.png
# Processed: data/data_3/convendrÃ­a.png
# Processed: data/data_3/convengamos (2).png
# Processed: data/data_3/convengamos.png
# Processed: data/data_3/conveniente (2).png
# Processed: data/data_3/conveniente. (2).png
# Processed: data/data_3/conveniente..png
# Processed: data/data_3/conveniente.png
# Processed: data/data_3/conveniente_1.png
# Processed: data/data_3/conveniente_2.png
# Processed: data/data_3/convenirse (2).png
# Processed: data/data_3/convenirse.png
# Processed: data/data_3/conviene (2).png
# Processed: data/data_3/conviene.png
# Processed: data/data_3/convienen (2).png
# Processed: data/data_3/convienen.png
# Processed: data/data_3/conviene_1.png
# Processed: data/data_3/convinaciones, (2).png
# Processed: data/data_3/convinaciones,.png
# Processed: data/data_3/convinaciones,_1.png
# Processed: data/data_3/con_1.png
# Processed: data/data_3/con_11.png
# Processed: data/data_3/con_13.png
# Processed: data/data_3/con_14.png
# Processed: data/data_3/con_16.png
# Processed: data/data_3/con_18.png
# Processed: data/data_3/con_20.png
# Processed: data/data_3/con_21.png
# Processed: data/data_3/con_23.png
# Processed: data/data_3/con_24.png
# Processed: data/data_3/con_25.png
# Processed: data/data_3/con_26.png
# Processed: data/data_3/con_27.png
# Processed: data/data_3/con_29.png
# Processed: data/data_3/con_30.png
# Processed: data/data_3/con_31.png
# Processed: data/data_3/con_32.png
# Processed: data/data_3/con_33.png
# Processed: data/data_3/con_35.png
# Processed: data/data_3/con_36.png
# Processed: data/data_3/con_37.png
# Processed: data/data_3/con_39.png
# Processed: data/data_3/con_4.png
# Processed: data/data_3/con_40.png
# Processed: data/data_3/con_41.png
# Processed: data/data_3/con_44.png
# Processed: data/data_3/con_46.png
# Processed: data/data_3/con_47.png
# Processed: data/data_3/con_5.png
# Processed: data/data_3/con_7.png
# Processed: data/data_3/con_8.png
# Processed: data/data_3/con_9.png
# Processed: data/data_3/corazÃ³n (2).png
# Processed: data/data_3/corazÃ³n.png
# Processed: data/data_3/corresponda, (2).png
# Processed: data/data_3/corresponda,.png
# Processed: data/data_3/corrompido, (2).png
# Processed: data/data_3/corrompido,.png
# Processed: data/data_3/Cortes (2).png
# Processed: data/data_3/Cortes.png
# Processed: data/data_3/cosa, (2).png
# Processed: data/data_3/cosa,.png
# Processed: data/data_3/cosa..png
# Processed: data/data_3/cosa.png
# Processed: data/data_3/cosas (2).png
# Processed: data/data_3/cosas, (2).png
# Processed: data/data_3/cosas,.png
# Processed: data/data_3/cosas,_1.png
# Processed: data/data_3/cosas.png
# Processed: data/data_3/cosas_3.png
# Processed: data/data_3/cosa_1.png
# Processed: data/data_3/cosa_2.png
# Processed: data/data_3/cosa_3.png
# Processed: data/data_3/costa.png
# Processed: data/data_3/costumbres (2).png
# Processed: data/data_3/costumbres.png
# Processed: data/data_3/costumbres_1.png
# Processed: data/data_3/costumbres_2.png
# Processed: data/data_3/costumbres_3.png
# Processed: data/data_3/costumbres_4.png
# Processed: data/data_3/cotejar (2).png
# Processed: data/data_3/cotejar.png
# Processed: data/data_3/cotejo.png
# Processed: data/data_3/creaciÃ³n.png
# Processed: data/data_3/creer,.png
# Processed: data/data_3/criado (2).png
# Processed: data/data_3/criado.png
# Processed: data/data_3/criado_1.png
# Processed: data/data_3/criado_2.png
# Processed: data/data_3/crÃ­an (2).png
# Processed: data/data_3/crÃ­an.png
# Processed: data/data_3/cuentan (2).png
# Processed: data/data_3/cuentan.png
# Processed: data/data_3/cuerpo,.png
# Processed: data/data_3/cuerpo. (2).png
# Processed: data/data_3/cuerpo..png
# Processed: data/data_3/cuerpo._1.png
# Processed: data/data_3/cuerpos, (2).png
# Processed: data/data_3/cuerpos,.png
# Processed: data/data_3/cuesta (2).png
# Processed: data/data_3/cuesta.png
# Processed: data/data_3/cuidado (2).png
# Processed: data/data_3/curiosidad_1.png
# Processed: data/data_3/cursan (2).png
# Processed: data/data_3/cursan.png
# Processed: data/data_3/curso (2).png
# Processed: data/data_3/curso.png
# Processed: data/data_3/cuya (2).png
# Processed: data/data_3/cuya_1.png
# Processed: data/data_3/cuyo (2).png
# Processed: data/data_3/cuyo.png
# Processed: data/data_3/cuyos.png
# Processed: data/data_3/cuyos_1.png
# Processed: data/data_3/cuyo_1.png
# Processed: data/data_3/Czar (2).png
# Processed: data/data_3/Czar.png
# Processed: data/data_3/cÃ³mo.png
# Processed: data/data_3/cÃ³mo_1.png
# Processed: data/data_3/cÃ³mo_2.png
# Processed: data/data_3/da (2).png
# Processed: data/data_3/da.png
# Processed: data/data_3/dado.png
# Processed: data/data_3/dan.png
# Processed: data/data_3/dar_2.png
# Processed: data/data_3/dar_3.png
# Processed: data/data_3/daÃ±os (2).png
# Processed: data/data_3/daÃ±os.png
# Processed: data/data_3/daÃ±os_1.png
# Processed: data/data_3/de (2).png
# Processed: data/data_3/de (3).png
# Processed: data/data_3/de (4).png
# Processed: data/data_3/de (5).png
# Processed: data/data_3/de (6).png
# Processed: data/data_3/de (7).png
# Processed: data/data_3/de.png
# Processed: data/data_3/debe, (2).png
# Processed: data/data_3/debe,.png
# Processed: data/data_3/debe.png
# Processed: data/data_3/debemos.png
# Processed: data/data_3/deben.png
# Processed: data/data_3/deben_1.png
# Processed: data/data_3/deben_2.png
# Processed: data/data_3/deben_3.png
# Processed: data/data_3/deberÃ­a.png
# Processed: data/data_3/debe_1.png
# Processed: data/data_3/debe_2.png
# Processed: data/data_3/debe_3.png
# Processed: data/data_3/debe_4.png
# Processed: data/data_3/debe_5.png
# Processed: data/data_3/debe_6.png
# Processed: data/data_3/debida.png
# Processed: data/data_3/debida_1.png
# Processed: data/data_3/decide, (2).png
# Processed: data/data_3/decide,.png
# Processed: data/data_3/decidieron (2).png
# Processed: data/data_3/decidieron.png
# Processed: data/data_3/decidir (2).png
# Processed: data/data_3/decidir.png
# Processed: data/data_3/decidir_1.png
# Processed: data/data_3/decir,.png
# Processed: data/data_3/decir,_1.png
# Processed: data/data_3/decir.png
# Processed: data/data_3/declamaciones (2).png
# Processed: data/data_3/declamaciones.png
# Processed: data/data_3/declarada (2).png
# Processed: data/data_3/declarada.png
# Processed: data/data_3/dedica (2).png
# Processed: data/data_3/dedica.png
# Processed: data/data_3/deduciendo (2).png
# Processed: data/data_3/deduciendo.png
# Processed: data/data_3/defensa.png
# Processed: data/data_3/defensa_2.png
# Processed: data/data_3/defiendan (2).png
# Processed: data/data_3/defiendan.png
# Processed: data/data_3/degradada (2).png
# Processed: data/data_3/degradada.png
# Processed: data/data_3/dejan (2).png
# Processed: data/data_3/dejan.png
# Processed: data/data_3/del (2).png
# Processed: data/data_3/del (3).png
# Processed: data/data_3/del (4).png
# Processed: data/data_3/del.png
# Processed: data/data_3/deliberaciones (2).png
# Processed: data/data_3/deliberaciones.png
# Processed: data/data_3/del_1.png
# Processed: data/data_3/del_10.png
# Processed: data/data_3/del_11.png
# Processed: data/data_3/del_12.png
# Processed: data/data_3/del_14.png
# Processed: data/data_3/del_15.png
# Processed: data/data_3/del_16.png
# Processed: data/data_3/del_17.png
# Processed: data/data_3/del_19.png
# Processed: data/data_3/del_2.png
# Processed: data/data_3/del_20.png
# Processed: data/data_3/del_21.png
# Processed: data/data_3/del_22.png
# Processed: data/data_3/del_23.png
# Processed: data/data_3/del_24.png
# Processed: data/data_3/del_25.png
# Processed: data/data_3/del_26.png
# Processed: data/data_3/del_29.png
# Processed: data/data_3/del_30.png
# Processed: data/data_3/del_31.png
# Processed: data/data_3/del_32.png
# Processed: data/data_3/del_34.png
# Processed: data/data_3/del_39.png
# Processed: data/data_3/del_45.png
# Processed: data/data_3/del_48.png
# Processed: data/data_3/del_5.png
# Processed: data/data_3/del_50.png
# Processed: data/data_3/del_6.png
# Processed: data/data_3/del_9.png
# Processed: data/data_3/dependencia.png
# Processed: data/data_3/dependientes. (2).png
# Processed: data/data_3/dependientes..png
# Processed: data/data_3/derecho (2).png
# Processed: data/data_3/derecho.png
# Processed: data/data_3/derogÃ³ (2).png
# Processed: data/data_3/derogÃ³.png
# Processed: data/data_3/des.png
# Processed: data/data_3/desacreditando (2).png
# Processed: data/data_3/desacreditando.png
# Processed: data/data_3/desaires (2).png
# Processed: data/data_3/desaires.png
# Processed: data/data_3/desanimado, (2).png
# Processed: data/data_3/desanimado,.png
# Processed: data/data_3/descubierto (2).png
# Processed: data/data_3/descubierto.png
# Processed: data/data_3/descubrimiento (2).png
# Processed: data/data_3/descubrimiento.png
# Processed: data/data_3/desde.png
# Processed: data/data_3/desdenes.png
# Processed: data/data_3/desea (2).png
# Processed: data/data_3/desea.png
# Processed: data/data_3/desean (2).png
# Processed: data/data_3/desean.png
# Processed: data/data_3/desear (2).png
# Processed: data/data_3/desear.png
# Processed: data/data_3/desearse (2).png
# Processed: data/data_3/desearse.png
# Processed: data/data_3/desempeÃ±ar (2).png
# Processed: data/data_3/desempeÃ±ar.png
# Processed: data/data_3/desentendernos (2).png
# Processed: data/data_3/desentendernos.png
# Processed: data/data_3/deseo.png
# Processed: data/data_3/deseos, (2).png
# Processed: data/data_3/deseos,.png
# Processed: data/data_3/desigualdad (2).png
# Processed: data/data_3/desigualdad.png
# Processed: data/data_3/desmayar, (2).png
# Processed: data/data_3/desmayar,.png
# Processed: data/data_3/desorden, (2).png
# Processed: data/data_3/desorden,.png
# Processed: data/data_3/desorden.png
# Processed: data/data_3/desorden_1.png
# Processed: data/data_3/despojado (2).png
# Processed: data/data_3/despojado.png
# Processed: data/data_3/despoje (2).png
# Processed: data/data_3/despoje.png
# Processed: data/data_3/desprecian (2).png
# Processed: data/data_3/desprecian.png
# Processed: data/data_3/desprecio; (2).png
# Processed: data/data_3/desprecio;.png
# Processed: data/data_3/despuÃ©s (2).png
# Processed: data/data_3/despuÃ©s.png
# Processed: data/data_3/despuÃ©s_1.png
# Processed: data/data_3/despuÃ©s_2.png
# Processed: data/data_3/despuÃ©s_3.png
# Processed: data/data_3/despuÃ©s_4.png
# Processed: data/data_3/despuÃ©s_5.png
# Processed: data/data_3/despuÃ©s_6.png
# Processed: data/data_3/despuÃ©s_7.png
# Processed: data/data_3/despuÃ©s_8.png
# Processed: data/data_3/desterradas (2).png
# Processed: data/data_3/desterradas.png
# Processed: data/data_3/desterrar (2).png
# Processed: data/data_3/desterrar.png
# Processed: data/data_3/destruir (2).png
# Processed: data/data_3/destruir.png
# Processed: data/data_3/desvanezcan (2).png
# Processed: data/data_3/desvanezcan.png
# Processed: data/data_3/desvelan (2).png
# Processed: data/data_3/desvelan.png
# Processed: data/data_3/desvelarse (2).png
# Processed: data/data_3/desvelarse.png
# Processed: data/data_3/desvelo, (2).png
# Processed: data/data_3/desvelo,.png
# Processed: data/data_3/desÃ³rdenes (2).png
# Processed: data/data_3/desÃ³rdenes.png
# Processed: data/data_3/dexaron (2).png
# Processed: data/data_3/dexaron.png
# Processed: data/data_3/deydades, (2).png
# Processed: data/data_3/deydades,.png
# Processed: data/data_3/de_10.png
# Processed: data/data_3/de_100.png
# Processed: data/data_3/de_101.png
# Processed: data/data_3/de_104.png
# Processed: data/data_3/de_108.png
# Processed: data/data_3/de_109.png
# Processed: data/data_3/de_11.png
# Processed: data/data_3/de_48.png
# Processed: data/data_3/de_49.png
# Processed: data/data_3/de_5.png
# Processed: data/data_3/de_50.png
# Processed: data/data_3/de_51.png
# Processed: data/data_3/de_52.png
# Processed: data/data_3/de_53.png
# Processed: data/data_3/de_54.png
# Processed: data/data_3/de_56.png
# Processed: data/data_3/de_58.png
# Processed: data/data_3/de_59.png
# Processed: data/data_3/de_60.png
# Processed: data/data_3/de_63.png
# Processed: data/data_3/de_64.png
# Processed: data/data_3/de_65.png
# Processed: data/data_3/de_69.png
# Processed: data/data_3/de_75.png
# Processed: data/data_3/de_78.png
# Processed: data/data_3/de_79.png
# Processed: data/data_3/de_8.png
# Processed: data/data_3/de_80.png
# Processed: data/data_3/de_81.png
# Processed: data/data_3/de_82.png
# Processed: data/data_3/de_83.png
# Processed: data/data_3/de_84.png
# Processed: data/data_3/de_85.png
# Processed: data/data_3/de_86.png
# Processed: data/data_3/de_87.png
# Processed: data/data_3/de_88.png
# Processed: data/data_3/de_9.png
# Processed: data/data_3/de_90.png
# Processed: data/data_3/de_91.png
# Processed: data/data_3/de_92.png
# Processed: data/data_3/de_93.png
# Processed: data/data_3/de_94.png
# Processed: data/data_3/de_96.png
# Processed: data/data_3/de_97.png
# Processed: data/data_3/de_98.png
# Processed: data/data_3/de_99.png
# Processed: data/data_3/dicho (2).png
# Processed: data/data_3/dicho, (2).png
# Processed: data/data_3/dicho,.png
# Processed: data/data_3/dicho.png
# Processed: data/data_3/dicho_1.png
# Processed: data/data_3/dictamen, (2).png
# Processed: data/data_3/dictamen,.png
# Processed: data/data_3/dictamen,_1.png
# Processed: data/data_3/diese (2).png
# Processed: data/data_3/diese.png
# Processed: data/data_3/diesen (2).png
# Processed: data/data_3/diesen.png
# Processed: data/data_3/diferente.png
# Processed: data/data_3/dificultades. (2).png
# Processed: data/data_3/dificultades..png
# Processed: data/data_3/difÃ­cil.png
# Processed: data/data_3/digamos,.png
# Processed: data/data_3/digna (2).png
# Processed: data/data_3/digna, (2).png
# Processed: data/data_3/digna,.png
# Processed: data/data_3/digna.png
# Processed: data/data_3/dignas (2).png
# Processed: data/data_3/dignas.png
# Processed: data/data_3/digno (2).png
# Processed: data/data_3/digno,.png
# Processed: data/data_3/digno,_1.png
# Processed: data/data_3/digno.png
# Processed: data/data_3/digno_2.png
# Processed: data/data_3/Digo (2).png
# Processed: data/data_3/Digo.png
# Processed: data/data_3/diligencias (2).png
# Processed: data/data_3/diligencias.png
# Processed: data/data_3/Dios, (2).png
# Processed: data/data_3/Dios,.png
# Processed: data/data_3/Dios.png
# Processed: data/data_3/Diotima, (2).png
# Processed: data/data_3/Diotima,.png
# Processed: data/data_3/diremos (2).png
# Processed: data/data_3/diremos.png
# Processed: data/data_3/dirigida (2).png
# Processed: data/data_3/dirigida.png
# Processed: data/data_3/dirÃ¡n (2).png
# Processed: data/data_3/dirÃ¡n.png
# Processed: data/data_3/dirÃ­a (2).png
# Processed: data/data_3/dirÃ­a, (2).png
# Processed: data/data_3/dirÃ­a,.png
# Processed: data/data_3/dirÃ­a.png
# Processed: data/data_3/dirÃ­a_1.png
# Processed: data/data_3/discreciÃ³n, (2).png
# Processed: data/data_3/discreciÃ³n,.png
# Processed: data/data_3/discreciÃ³n,_2.png
# Processed: data/data_3/Discurso (2).png
# Processed: data/data_3/Discurso.png
# Processed: data/data_3/discÃ­pulo (2).png
# Processed: data/data_3/discÃ­pulo.png
# Processed: data/data_3/disipan (2).png
# Processed: data/data_3/disipan.png
# Processed: data/data_3/disolucion..png
# Processed: data/data_3/disposiciÃ³n (2).png
# Processed: data/data_3/disposiciÃ³n.png
# Processed: data/data_3/disposiciÃ³n_1.png
# Processed: data/data_3/disputa, (2).png
# Processed: data/data_3/disputa,.png
# Processed: data/data_3/disputa. (2).png
# Processed: data/data_3/disputa..png
# Processed: data/data_3/disputas (2).png
# Processed: data/data_3/disputas.png
# ...
# Processed: data/data_3/tomen.png
# Processed: data/data_3/TomÃ¡s, (2).png
# Processed: data/data_3/TomÃ¡s,.png
# Processed: data/data_3/total (2).png
# Processed: data/data_3/total.png
# Processed: data/data_3/trabajar.png
# Processed: data/data_3/trabajar_1.png
# Processed: data/data_3/trabajar_2.png
# Processed: data/data_3/trabaje (2).png
# Processed: data/data_3/trabaje.png
# Processed: data/data_3/trabajen (2).png
# Processed: data/data_3/trabajen.png
# Processed: data/data_3/trabajos, (2).png
# Processed: data/data_3/trabajos,.png
# Processed: data/data_3/trata (2).png
# Processed: data/data_3/trata.png
# Processed: data/data_3/Tratado (2).png
# Processed: data/data_3/Tratado.png
# Processed: data/data_3/tratan (2).png
# Processed: data/data_3/tratan.png
# Processed: data/data_3/Tratando (2).png
# Processed: data/data_3/Tratando.png
# Processed: data/data_3/tratan_2.png
# Processed: data/data_3/tratan_3.png
# Processed: data/data_3/tratar (2).png
# Processed: data/data_3/tratar.png
# Processed: data/data_3/tratasen (2).png
# Processed: data/data_3/tratasen.png
# Processed: data/data_3/trata_1.png
# Processed: data/data_3/trata_2.png
# Processed: data/data_3/Tratemos (2).png
# Processed: data/data_3/Tratemos.png
# Processed: data/data_3/trato (2).png
# Processed: data/data_3/trato.png
# Processed: data/data_3/trato_1.png
# Processed: data/data_3/trofeos (2).png
# Processed: data/data_3/trofeos.png
# Processed: data/data_3/tropas.png
# Processed: data/data_3/tubieran (2).png
# Processed: data/data_3/tuvo.png
# Processed: data/data_3/tuvo_1.png
# Processed: data/data_3/tÃ­tulo (2).png
# Processed: data/data_3/tÃ­tulo.png
# Processed: data/data_3/tÃ­tulos (2).png
# Processed: data/data_3/tÃ­tulos.png
# Processed: data/data_3/ultima.png
# Processed: data/data_3/un (2).png
# Processed: data/data_3/Una (2).png
# Processed: data/data_3/una, (2).png
# Processed: data/data_3/una,.png
# Processed: data/data_3/una,_1.png
# Processed: data/data_3/una.png
# Processed: data/data_3/unas (2).png
# Processed: data/data_3/unas, (2).png
# Processed: data/data_3/unas,.png
# Processed: data/data_3/unas.png
# Processed: data/data_3/unas_2.png
# Processed: data/data_3/una_10.png
# Processed: data/data_3/una_12.png
# Processed: data/data_3/una_17.png
# Processed: data/data_3/valor (2).png
# Processed: data/data_3/valor, (2).png
# Processed: data/data_3/valor,.png
# Processed: data/data_3/valor,_1.png
# Processed: data/data_3/valor_1.png
# Processed: data/data_3/van (2).png
# Processed: data/data_3/van.png
# Processed: data/data_3/vana (2).png
# Processed: data/data_3/vana.png
# Processed: data/data_3/vanidad, (2).png
# Processed: data/data_3/vanidad,.png
# Processed: data/data_3/varias.png
# Processed: data/data_3/varias_1.png
# Processed: data/data_3/ve.png
# Processed: data/data_3/veces, (2).png
# Processed: data/data_3/veces,.png
# Processed: data/data_3/veces,_1.png
# Processed: data/data_3/veces.png
# Processed: data/data_3/veces_2.png
# Processed: data/data_3/vedada, (2).png
# Processed: data/data_3/vedada,.png
# Processed: data/data_3/vehementes (2).png
# Processed: data/data_3/vehementes.png
# Processed: data/data_3/vejez, (2).png
# Processed: data/data_3/vejez,.png
# Processed: data/data_3/Vemos (2).png
# Processed: data/data_3/vemos, (2).png
# Processed: data/data_3/vemos,.png
# Processed: data/data_3/Vemos.png
# Processed: data/data_3/Vemos_1.png
# Processed: data/data_3/ven (2).png
# Processed: data/data_3/ven.png
# Processed: data/data_3/vender. (2).png
# Processed: data/data_3/vender..png
# Processed: data/data_3/veneraciÃ³n. (2).png
# Processed: data/data_3/veneraciÃ³n..png
# Processed: data/data_3/ventaja.png
# Processed: data/data_3/ventaja_1.png
# Processed: data/data_3/ventaja_2.png
# Processed: data/data_3/ventaja_3.png
# Processed: data/data_3/ventaja_4.png
# Processed: data/data_3/ventajosas (2).png
# Processed: data/data_3/ventajosas.png
# Processed: data/data_3/ventura.png
# Processed: data/data_3/ventura_1.png
# Processed: data/data_3/ver (2).png
# Processed: data/data_3/ver.png
# Processed: data/data_3/veras, (2).png
# Processed: data/data_3/veras,.png
# Processed: data/data_3/verdad,.png
# Processed: data/data_3/verdad,_1.png
# Processed: data/data_3/verdadera (2).png
# Processed: data/data_3/verdadera.png
# Processed: data/data_3/verdaderamente (2).png
# Processed: data/data_3/verdaderamente.png
# Processed: data/data_3/verifica (2).png
# Processed: data/data_3/verifica.png
# Processed: data/data_3/verificarse (2).png
# Processed: data/data_3/verificarse.png
# Processed: data/data_3/verifique (2).png
# Processed: data/data_3/verifique.png
# Processed: data/data_3/versado (2).png
# Processed: data/data_3/versado.png
# Processed: data/data_3/verse (2).png
# Processed: data/data_3/verse.png
# Processed: data/data_3/verse_1.png
# Processed: data/data_3/verse_2.png
# Processed: data/data_3/ver_1.png
# Processed: data/data_3/ver_3.png
# Processed: data/data_3/ver_4.png
# Processed: data/data_3/verÃ­a (2).png
# Processed: data/data_3/verÃ­a.png
# Processed: data/data_3/VerÃ­an (2).png
# Processed: data/data_3/VerÃ­an.png
# Processed: data/data_3/vez (2).png
# Processed: data/data_3/vez.png
# Processed: data/data_3/ve_1.png
# Processed: data/data_3/ve_2.png
# Processed: data/data_3/vicio, (2).png
# Processed: data/data_3/vicio,.png
# Processed: data/data_3/vicios.png
# Processed: data/data_3/victoria, (2).png
# Processed: data/data_3/victoria,.png
# Processed: data/data_3/y_84.png
# Processed: data/data_3/y_85.png
# Processed: data/data_3/y_87.png
# Processed: data/data_3/y_88.png
# Processed: data/data_3/y_89.png
# Processed: data/data_3/y_9.png
# Processed: data/data_3/y_90.png
# Processed: data/data_3/y_91.png
# Processed: data/data_3/y_92.png
# Processed: data/data_3/y_93.png
# Processed: data/data_3/y_94.png
# Processed: data/data_3/y_95.png
# Processed: data/data_3/y_96.png
# Processed: data/data_3/y_97.png
# Processed: data/data_3/y_99.png
# Processed: data/data_3/Zaragoza (2).png
# Processed: data/data_3/Zaragoza.png
# Processed: data/data_3/Zontano, (2).png
# Processed: data/data_3/Zontano,.png
# Processed: data/data_3/Â¡Exemplo.png
# Processed: data/data_3/Â¿Mas_2.png
# Processed: data/data_3/Â¿Ni.png
# Processed: data/data_3/Â¿No_3.png
# Processed: data/data_3/Â¿Por_1.png
# Processed: data/data_3/Â¿Por_2.png
# Processed: data/data_3/Â¿Puede.png
# Processed: data/data_3/Â¿pues,.png
# Processed: data/data_3/Â¿Son.png
# Processed: data/data_3/Ã©.png
# Processed: data/data_3/Ã©stas,.png
# Processed: data/data_3/Ã©stas,_1.png
# Processed: data/data_3/Ã©stas,_2.png
# Processed: data/data_3/Ã©stas,_3.png
# Processed: data/data_3/Ã©stas,_4.png
# Processed: data/data_3/Ã©stas.png
# Processed: data/data_3/Ã©stas;.png
# Processed: data/data_3/Ã©stas_1.png
# Processed: data/data_3/Ã©stas_2.png
# Processed: data/data_3/Ã©stas_3.png
# Processed: data/data_3/Ã©sta_3.png
# Processed: data/data_3/Ã©ste,.png
# Processed: data/data_3/Ã©ste,_1.png
# Processed: data/data_3/Ã©ste,_2.png
# Processed: data/data_3/Ã©ste.png
# Processed: data/data_3/Ã©ste_1.png
# Processed: data/data_3/Ã©ste_2.png
# Processed: data/data_3/Ã©stos.png
# Processed: data/data_3/Ã©stos_1.png
# Processed: data/data_3/Ãºltima,.png
# Processed: data/data_3/Ãºtiles_2.png
# Processed: data/data_3/Ãºtiles_3.png
#
# --- Summary ---
# Total images found       : 5838
# Successfully processed   : 5838
# Skipped due to errors    : 0

# %% [markdown]
# Download Manually Corrected Dataset

# %%
import gdown
import zipfile
import os

# Google Drive file ID of the ZIP file
zip_output_path = 'data/downloaded_folder.zip'

# Construct download URL
gdown.download(f'https://drive.google.com/file/d/1AmciGFL8YFFgqdvhL7e5T4GPkoGhMnUq', zip_output_path, quiet=False)

# Unzip the downloaded file
with zipfile.ZipFile(zip_output_path, 'r') as zip_ref:
    zip_ref.extractall('unzipped_folder')

# Optional: remove the zip file after extraction
os.remove(zip_output_path)

# %%
import cv2
import numpy as np
import os
from glob import glob

import cv2, os
from glob import glob

import numpy as np
import cv2

def imread_unicode(path, flags=cv2.IMREAD_COLOR):
    # read raw bytes, then decode in-memory
    data = open(path, "rb").read()
    arr  = np.frombuffer(data, dtype=np.uint8)
    return cv2.imdecode(arr, flags)

# %%
from utils import pad_and_resize_images

pad_and_resize_images("data/data_9")
# Out:
# Processed: data/data_9\A.png
# Processed: data/data_9\Análisis.png
# Processed: data/data_9\Anárquico.png
# Processed: data/data_9\Aquí.png
# Processed: data/data_9\Auténtico.png
# Processed: data/data_9\Bambú.png
# Processed: data/data_9\Bilingüísimo.png
# Processed: data/data_9\Botón.png
# Processed: data/data_9\Brújula.png
# Processed: data/data_9\Bélgica.png
# Processed: data/data_9\Bénito.png
# Processed: data/data_9\Camióncillo.png
# Processed: data/data_9\Canción.png
# Processed: data/data_9\Clásico (2).png
# Processed: data/data_9\Clásico.png
# Processed: data/data_9\Colón.png
# Processed: data/data_9\Corazón.png
# Processed: data/data_9\Creéis.png
# Processed: data/data_9\Cáculo.png
# Processed: data/data_9\Cáliz (2).png
# Processed: data/data_9\Cáliz.png
# Processed: data/data_9\Cámara.png
# Processed: data/data_9\Cántaro.png
# Processed: data/data_9\Cántico.png
# Processed: data/data_9\Cárcel.png
# Processed: data/data_9\Céfiro.png
# Processed: data/data_9\Césped.png
# Processed: data/data_9\Códice.png
# Processed: data/data_9\Cúbico.png
# Processed: data/data_9\Cúmulo.png
# Processed: data/data_9\Cúrcuma.png
# Processed: data/data_9\Cúspide.png
# Processed: data/data_9\Debéis.png
# Processed: data/data_9\Después.png
# Processed: data/data_9\Espíritus.png
# Processed: data/data_9\Estrés.png
# Processed: data/data_9\Exégeta.png
# Processed: data/data_9\Francés.png
# Processed: data/data_9\Fácil.png
# Processed: data/data_9\Féretro.png
# Processed: data/data_9\Fósforo.png
# Processed: data/data_9\Fútbol.png
# Processed: data/data_9\HuÉsped.png
# Processed: data/data_9\Héroe.png
# Processed: data/data_9\Inglés.png
# Processed: data/data_9\Inúmeros.png
# Processed: data/data_9\Inútil.png
# Processed: data/data_9\Jamás (2).png
# Processed: data/data_9\Jamás.png
# Processed: data/data_9\Jardín.png
# Processed: data/data_9\Júbilo.png
# Processed: data/data_9\Legítimo.png
# Processed: data/data_9\Lágrima.png
# Processed: data/data_9\Lápiz.png
# Processed: data/data_9\Lógica.png
# Processed: data/data_9\Lúcido.png
# Processed: data/data_9\Lúgubre.png
# Processed: data/data_9\Maní.png
# Processed: data/data_9\María.png
# Processed: data/data_9\Menú.png
# Processed: data/data_9\Miércoles.png
# Processed: data/data_9\Murciélago.png
# Processed: data/data_9\Mágico.png
# Processed: data/data_9\Máquina.png
# Processed: data/data_9\Mármol.png
# Processed: data/data_9\Mártir.png
# Processed: data/data_9\Más (2).png
# Processed: data/data_9\Más.png
# Processed: data/data_9\Médico.png
# Processed: data/data_9\Métrica.png
# Processed: data/data_9\Mío.png
# Processed: data/data_9\Mísero.png
# Processed: data/data_9\Móvil.png
# Processed: data/data_9\Músculo.png
# Processed: data/data_9\Opción.png
# Processed: data/data_9\Panamá.png
# Processed: data/data_9\Perfido.png
# Processed: data/data_9\Prólogo (2).png
# Processed: data/data_9\Prólogo.png
# Processed: data/data_9\Próximo.png
# Processed: data/data_9\Página.png
# Processed: data/data_9\Pájaro.png
# Processed: data/data_9\Pólvora.png
# Processed: data/data_9\Público.png
# Processed: data/data_9\Ración.png
# Processed: data/data_9\Raíz.png
# Processed: data/data_9\Rápido.png
# Processed: data/data_9\Récord.png
# Processed: data/data_9\Régimen.png
# Processed: data/data_9\Réplica.png
# Processed: data/data_9\Rótula.png
# Processed: data/data_9\Rúbrica.png
# Processed: data/data_9\Sábana.png
# Processed: data/data_9\Séptimo.png
# Processed: data/data_9\Sólido.png
# Processed: data/data_9\Súbito.png
# Processed: data/data_9\Súper.png
# Processed: data/data_9\Tráiler.png
# Processed: data/data_9\Trípode.png
# Processed: data/data_9\Tímido.png
# Processed: data/data_9\Tórax.png
# Processed: data/data_9\Tóxico.png
# Processed: data/data_9\Túnel.png
# Processed: data/data_9\vión.png
# Processed: data/data_9\¡Ay!.png
# Processed: data/data_9\¡Bebé!.png
# Processed: data/data_9\¡Qué! (2).png
# Processed: data/data_9\¡Qué!.png
# Processed: data/data_9\¡Sí!.png
# Processed: data/data_9\¡Tú!.png
# Processed: data/data_9\¡Ánimo! (2).png
# Processed: data/data_9\¡Ánimo!.png
# Processed: data/data_9\¡Ídolo!.png
# Processed: data/data_9\¡Óyeme!.png
# Processed: data/data_9\Ácido.png
# Processed: data/data_9\Ágil.png
# Processed: data/data_9\Álvarez.png
# Processed: data/data_9\Ángel.png
# Processed: data/data_9\Árabe.png
# Processed: data/data_9\Árbol.png
# Processed: data/data_9\Área.png
# Processed: data/data_9\Árida.png
# Processed: data/data_9\Áurea.png
# Processed: data/data_9\Áureo.png
# Processed: data/data_9\Áureos.png
# Processed: data/data_9\Élite.png
# Processed: data/data_9\épico (2).png
# Processed: data/data_9\Épico.png
# Processed: data/data_9\Ética.png
# Processed: data/data_9\Éxito.png
# Processed: data/data_9\Ídolo.png
# Processed: data/data_9\Índice.png
# Processed: data/data_9\Íntimo.png
# Processed: data/data_9\Íntimos.png
# Processed: data/data_9\Último.png
# Processed: data/data_9\Único (2).png
# Processed: data/data_9\Único.png
# Processed: data/data_9\Úrsula.png
#
# --- Summary ---
# Total images found       : 138
# Successfully processed   : 138
# Skipped due to errors    : 0

# %%
from pathlib import Path
import re
import cv2
from collections import defaultdict

# %%
# ─── RUN: Full-Folder Word Extraction ───
from pathlib import Path
# import your function (adjust the import path if needed)

# 1) Define folders
boxes_folder          = "output/craft/boxes_sorted"
transcriptions_folder = "data/transcriptions"
images_folder         = "data/pages"
output_folder         = "data/training_words/test"

# 2) Ensure output parent exists
Path(output_folder).mkdir(parents=True, exist_ok=True)

# 3) Run the alignment + extraction
align_and_extract_words(
    boxes_folder=boxes_folder,
    transcriptions_folder=transcriptions_folder,
    images_folder=images_folder,
    output_folder=output_folder
)
# Out:
# ✅ Saved 7127 word crops to data\training_words\test\cropped
# ✅ Labels saved to data\training_words\test\labels.csv

# %%
import os

folder = "data/data_4"
for fname in os.listdir(folder):
    new_name = fname.replace(" - Copy.png", ".png")
    os.rename(os.path.join(folder, fname), os.path.join(folder, new_name))
    print(f"Renamed: {fname} → {new_name}")
# Out:
# Renamed: a (28).png → a (28).png
# Renamed: a (34).png → a (34).png
# Renamed: a (37).png → a (37).png
# Renamed: a (38).png → a (38).png
# Renamed: a (40).png → a (40).png
# Renamed: a (41).png → a (41).png
# Renamed: a (46).png → a (46).png
# Renamed: a (47).png → a (47).png
# Renamed: a (48).png → a (48).png
# Renamed: a (7).png → a (7).png
# Renamed: A (8).png → A (8).png
# Renamed: acusado.png → acusado.png
# Renamed: ageno.png → ageno.png
# Renamed: al rostro,diximos.jpg → al rostro,diximos.jpg
# Renamed: alcanzase delas.png → alcanzase delas.png
# Renamed: algunos.png → algunos.png
# Renamed: allanar.png → allanar.png
# Renamed: alli.png → alli.png
# Renamed: Alléde.png → Alléde.png
# Renamed: alma.png → alma.png
# Renamed: alos (2).png → alos (2).png
# Renamed: altas.png → altas.png
# Renamed: amistad (2).png → amistad (2).png
# Renamed: amistad.png → amistad.png
# Renamed: amores (2).png → amores (2).png
# Renamed: animo.png → animo.png
# Renamed: antonio.png → antonio.png
# Renamed: apresuraua.png → apresuraua.png
# Renamed: aqllas.png → aqllas.png
# Renamed: aqllos.png → aqllos.png
# Renamed: ardiente.png → ardiente.png
# Renamed: armado.png → armado.png
# Renamed: armas.png → armas.png
# Renamed: artes (2).png → artes (2).png
# Renamed: asigna.png → asigna.png
# Renamed: asignados.png → asignados.png
# Renamed: aspero.png → aspero.png
# Renamed: athenes.png → athenes.png
# Renamed: atrevido.png → atrevido.png
# Renamed: atrevidos.png → atrevidos.png
# Renamed: auar.png → auar.png
# Renamed: auctoridad.png → auctoridad.png
# Renamed: auiá.png → auiá.png
# Renamed: avemos.png → avemos.png
# Renamed: avia (4).png → avia (4).png
# Renamed: Ay (2).png → Ay (2).png
# Renamed: B (2).png → B (2).png
# Renamed: B (3).png → B (3).png
# Renamed: B (4).png → B (4).png
# Renamed: bauer.png → bauer.png
# Renamed: bauia (2).png → bauia (2).png
# Renamed: bauia (3).png → bauia (3).png
# Renamed: bauia.png → bauia.png
# Renamed: bauian.png → bauian.png
# Renamed: bestia lucio.png → bestia lucio.png
# Renamed: bien (4).png → bien (4).png
# Renamed: bradaméte.png → bradaméte.png
# Renamed: bras.png → bras.png
# Renamed: bre.png → bre.png
# Renamed: brevedad.png → brevedad.png
# Renamed: breves.png → breves.png
# Renamed: buena (4).png → buena (4).png
# Renamed: Buena (5).png → Buena (5).png
# Renamed: buscavan.png → buscavan.png
# Renamed: cada (2).png → cada (2).png
# Renamed: cada (3).png → cada (3).png
# Renamed: cada (5).png → cada (5).png
# Renamed: cada (6).png → cada (6).png
# Renamed: capitá y.png → capitá y.png
# Renamed: casa (2).png → casa (2).png
# Renamed: casa.png → casa.png
# Renamed: casas (2).png → casas (2).png
# Renamed: casas (3).png → casas (3).png
# Renamed: castigados.png → castigados.png
# Renamed: Cathilina (2).png → Cathilina (2).png
# Renamed: Cathilina.png → Cathilina.png
# Renamed: cavalle.png → cavalle.png
# Renamed: cavallos que.png → cavallos que.png
# Renamed: cerca.png → cerca.png
# Renamed: cesar.png → cesar.png
# Renamed: cetego.png → cetego.png
# Renamed: ci.png → ci.png
# Renamed: cibdad.png → cibdad.png
# Renamed: cibdades.png → cibdades.png
# Renamed: cio Marcolecca Lucio.png → cio Marcolecca Lucio.png
# Renamed: cito (2).png → cito (2).png
# Renamed: co (8).png → co (8).png
# Renamed: co (9).png → co (9).png
# Renamed: cobdicia.png → cobdicia.png
# Renamed: cobdicioso.png → cobdicioso.png
# Renamed: combate si.png → combate si.png
# Renamed: combites.png → combites.png
# Renamed: comécado.png → comécado.png
# Renamed: con (22).png → con (22).png
# Renamed: con (27).png → con (27).png
# Renamed: Confiaua.png → Confiaua.png
# Renamed: congoran.png → congoran.png
# Renamed: conjuracion.png → conjuracion.png
# Renamed: conjuració.png → conjuració.png
# Renamed: conoscido.png → conoscido.png
# Renamed: consulado.png → consulado.png
# Renamed: consules (2).png → consules (2).png
# Renamed: consules Publio.png → consules Publio.png
# Renamed: consules.png → consules.png
# Renamed: contentavá.png → contentavá.png
# Renamed: corazon.png → corazon.png
# Renamed: cordura el.png → cordura el.png
# Renamed: cornelio.png → cornelio.png
# Renamed: corrompidas.png → corrompidas.png
# Renamed: costumbres.png → costumbres.png
# Renamed: costúbradas.png → costúbradas.png
# Renamed: costúbres.png → costúbres.png
# Renamed: crescie.png → crescie.png
# Renamed: cretaméte.png → cretaméte.png
# Renamed: curaua.png → curaua.png
# Renamed: curio Del.png → curio Del.png
# Renamed: có (5).png → có (5).png
# Renamed: có (7).png → có (7).png
# Renamed: cósulado pues.png → cósulado pues.png
# Renamed: dauana.png → dauana.png
# Renamed: de (101).png → de (101).png
# Renamed: de (105).png → de (105).png
# Renamed: de (110).png → de (110).png
# Renamed: de (111).png → de (111).png
# Renamed: de (123).png → de (123).png
# Renamed: de (131).png → de (131).png
# Renamed: de (132).png → de (132).png
# Renamed: de (133).png → de (133).png
# Renamed: de (134).png → de (134).png
# Renamed: de (135).png → de (135).png
# Renamed: de (136).png → de (136).png
# Renamed: de (137).png → de (137).png
# Renamed: de (138).png → de (138).png
# Renamed: de (139).png → de (139).png
# Renamed: de (140).png → de (140).png
# Renamed: de (141).png → de (141).png
# Renamed: de (142).png → de (142).png
# Renamed: de (143).png → de (143).png
# Renamed: de (144).png → de (144).png
# Renamed: de (145).png → de (145).png
# Renamed: de (146).png → de (146).png
# Renamed: de (147).png → de (147).png
# Renamed: defésar.png → defésar.png
# Renamed: del (23).png → del (23).png
# Renamed: del (24).png → del (24).png
# Renamed: del (25).png → del (25).png
# Renamed: dela (2).png → dela (2).png
# Renamed: dela (3).png → dela (3).png
# Renamed: delas (4).png → delas (4).png
# Renamed: delas (5).png → delas (5).png
# Renamed: delicada.png → delicada.png
# Renamed: delictos.png → delictos.png
# Renamed: delo (2).png → delo (2).png
# Renamed: delo (3).png → delo (3).png
# Renamed: delo (4).png → delo (4).png
# Renamed: delo.png → delo.png
# Renamed: delos (3).png → delos (3).png
# Renamed: delos (4).png → delos (4).png
# Renamed: delos (5).png → delos (5).png
# Renamed: delos (6).png → delos (6).png
# Renamed: demasiadaméte.png → demasiadaméte.png
# Renamed: demendaua.png → demendaua.png
# Renamed: demádar.png → demádar.png
# Renamed: derramador.png → derramador.png
# Renamed: derriban otras.png → derriban otras.png
# Renamed: deseos.png → deseos.png
# Renamed: despues (11).png → despues (11).png
# Renamed: despues (12).png → despues (12).png
# Renamed: despues (4).png → despues (4).png
# Renamed: dia (2).png → dia (2).png
# Renamed: dia.png → dia.png
# Renamed: dicho Marco.png → dicho Marco.png
# Renamed: dinero (2).png → dinero (2).png
# Renamed: dinero.png → dinero.png
# Renamed: discordias.png → discordias.png
# Renamed: disimulador.png → disimulador.png
# Renamed: domado.png → domado.png
# Renamed: dos (6).png → dos (6).png
# Renamed: dos (9).png → dos (9).png
# Renamed: détro.png → détro.png
# Renamed: E (10).png → E (10).png
# Renamed: E (12).png → E (12).png
# Renamed: edificá en.png → edificá en.png
# Renamed: el (42).png → el (42).png
# Renamed: El (48).png → El (48).png
# Renamed: el (49).png → el (49).png
# Renamed: el (50).png → el (50).png
# Renamed: el (51).png → el (51).png
# Renamed: ellos (3).png → ellos (3).png
# Renamed: ellos (4).png → ellos (4).png
# Renamed: ellos (5).png → ellos (5).png
# Renamed: Ellos (6).png → Ellos (6).png
# Renamed: en (63).png → en (63).png
# Renamed: en (64).png → en (64).png
# Renamed: en (65).png → en (65).png
# Renamed: en (66).png → en (66).png
# Renamed: en (67).png → en (67).png
# Renamed: en (68).png → en (68).png
# Renamed: en (69).png → en (69).png
# Renamed: endevida.png → endevida.png
# Renamed: enemi.png → enemi.png
# Renamed: enemigo (2).png → enemigo (2).png
# Renamed: enemigo (3).png → enemigo (3).png
# Renamed: enfalzar.png → enfalzar.png
# Renamed: entonce.png → entonce.png
# Renamed: entrado (2).png → entrado (2).png
# Renamed: entre (5).png → entre (5).png
# Renamed: era (8).png → era (8).png
# Renamed: era (9).png → era (9).png
# Renamed: era.png → era.png
# Renamed: erá.png → erá.png
# Renamed: es (10).png → es (10).png
# Renamed: es (11).png → es (11).png
# Renamed: es (12).png → es (12).png
# Renamed: esper.png → esper.png
# Renamed: esperanza (3).png → esperanza (3).png
# Renamed: esperáza.png → esperáza.png
# Renamed: este (10).png → este (10).png
# Renamed: esto (4).png → esto (4).png
# Renamed: eñl.png → eñl.png
# Renamed: fama (2).png → fama (2).png
# Renamed: fama (3).png → fama (3).png
# Renamed: familiares.png → familiares.png
# Renamed: fas.png → fas.png
# Renamed: favor (2).png → favor (2).png
# Renamed: fazia (2).png → fazia (2).png
# Renamed: fazia.png → fazia.png
# Renamed: fechas.png → fechas.png
# Renamed: fecho.png → fecho.png
# Renamed: fechos (2).png → fechos (2).png
# Renamed: ferir.png → ferir.png
# Renamed: fermosas.png → fermosas.png
# Renamed: feroce.png → feroce.png
# Renamed: figulo.png → figulo.png
# Renamed: fijieron.png → fijieron.png
# Renamed: fijo.png → fijo.png
# Renamed: fin.png → fin.png
# Renamed: fortificadas.png → fortificadas.png
# Renamed: fortuna (2).png → fortuna (2).png
# Renamed: fortuna (3).png → fortuna (3).png
# Renamed: forzo.png → forzo.png
# Renamed: fuese (2).png → fuese (2).png
# Renamed: g.png → g.png
# Renamed: gabinio.png → gabinio.png
# Renamed: galardon.png → galardon.png
# Renamed: ganaria.png → ganaria.png
# Renamed: gente.png → gente.png
# Renamed: gloria.png → gloria.png
# Renamed: gos (3).png → gos (3).png
# Renamed: gr.png → gr.png
# Renamed: gran (2).png → gran (2).png
# Renamed: grand (2).png → grand (2).png
# Renamed: grand (3).png → grand (3).png
# Renamed: grand (4).png → grand (4).png
# Renamed: grand (5).png → grand (5).png
# Renamed: grand (6).png → grand (6).png
# Renamed: grandes (2).png → grandes (2).png
# Renamed: grá (3).png → grá (3).png
# Renamed: grádes.png → grádes.png
# Renamed: guardava.png → guardava.png
# Renamed: gue.png → gue.png
# Renamed: gueo.png → gueo.png
# Renamed: guerras (2).png → guerras (2).png
# Renamed: guerreava.png → guerreava.png
# Renamed: havia (2).png → havia (2).png
# Renamed: havia.png → havia.png
# Renamed: havida.png → havida.png
# Renamed: honestas.png → honestas.png
# Renamed: hóbres.png → hóbres.png
# Renamed: injustas.png → injustas.png
# Renamed: joventud (2).png → joventud (2).png
# Renamed: joventud.png → joventud.png
# Renamed: La (56).png → La (56).png
# Renamed: la (71).png → la (71).png
# Renamed: la (72).png → la (72).png
# Renamed: La (74).png → La (74).png
# Renamed: la (75).png → la (75).png
# Renamed: la (76).png → la (76).png
# Renamed: la (77).png → la (77).png
# Renamed: la (78).png → la (78).png
# Renamed: la (81).png → la (81).png
# Renamed: la firme.png → la firme.png
# Renamed: la republica.png → la republica.png
# Renamed: las (21).png → las (21).png
# Renamed: las (23).png → las (23).png
# Renamed: las (24).png → las (24).png
# Renamed: las (25).png → las (25).png
# Renamed: las (26).png → las (26).png
# Renamed: las (27).png → las (27).png
# Renamed: las (28).png → las (28).png
# Renamed: Las (29).png → Las (29).png
# Renamed: lentulo.png → lentulo.png
# Renamed: leyendo.png → leyendo.png
# Renamed: liberales.png → liberales.png
# Renamed: libertad (2).png → libertad (2).png
# Renamed: libertad.png → libertad.png
# Renamed: llamo.png → llamo.png
# Renamed: Los (32).png → Los (32).png
# Renamed: los (33).png → los (33).png
# Renamed: los (34).png → los (34).png
# Renamed: los (35).png → los (35).png
# Renamed: los (36).png → los (36).png
# Renamed: los (37).png → los (37).png
# Renamed: los (38).png → los (38).png
# Renamed: los (39).png → los (39).png
# Renamed: los (40).png → los (40).png
# Renamed: los (41).png → los (41).png
# Renamed: los (42).png → los (42).png
# Renamed: los ingenios.png → los ingenios.png
# Renamed: lozia.png → lozia.png
# Renamed: Lucio (2).png → Lucio (2).png
# Renamed: Lucio (3).png → Lucio (3).png
# Renamed: Lucio.png → Lucio.png
# Renamed: lugares.png → lugares.png
# Renamed: Lócu.png → Lócu.png
# Renamed: lógino.png → lógino.png
# Renamed: magnificos.png → magnificos.png
# Renamed: manera (2).png → manera (2).png
# Renamed: mano.png → mano.png
# Renamed: mar (2).png → mar (2).png
# Renamed: mas (19).png → mas (19).png
# Renamed: mas (21).png → mas (21).png
# Renamed: mas (22).png → mas (22).png
# Renamed: mas (23).png → mas (23).png
# Renamed: mas (24).png → mas (24).png
# Renamed: mas (25).png → mas (25).png
# Renamed: mas (26).png → mas (26).png
# Renamed: mayor (5).png → mayor (5).png
# Renamed: mencióla.png → mencióla.png
# Renamed: mengua.png → mengua.png
# Renamed: menores.png → menores.png
# Renamed: mente.png → mente.png
# Renamed: mezquina.png → mezquina.png
# Renamed: mi (3).png → mi (3).png
# Renamed: mi (4).png → mi (4).png
# Renamed: miedo (2).png → miedo (2).png
# Renamed: misma (2).png → misma (2).png
# Renamed: misma.png → misma.png
# Renamed: miétras.png → miétras.png
# Renamed: montañas.png → montañas.png
# Renamed: moria.png → moria.png
# Renamed: mos.png → mos.png
# Renamed: mostrando.png → mostrando.png
# Renamed: Mouianlo.png → Mouianlo.png
# Renamed: movia.png → movia.png
# Renamed: movible.png → movible.png
# Renamed: mozo.png → mozo.png
# Renamed: mundo.png → mundo.png
# Renamed: muralla y.png → muralla y.png
# Renamed: muy (4).png → muy (4).png
# Renamed: muy (5).png → muy (5).png
# Renamed: múdo.png → múdo.png
# Renamed: naciones (2).png → naciones (2).png
# Renamed: natu.png → natu.png
# Renamed: nificaméte y.png → nificaméte y.png
# Renamed: ninguna (2).png → ninguna (2).png
# Renamed: ningú.png → ningú.png
# Renamed: ningúa.png → ningúa.png
# Renamed: no (25).png → no (25).png
# Renamed: no nos.png → no nos.png
# Renamed: noble (3).png → noble (3).png
# Renamed: noble.png → noble.png
# Renamed: nobles (2).png → nobles (2).png
# Renamed: nobles (3).png → nobles (3).png
# Renamed: nobles (4).png → nobles (4).png
# Renamed: nobles.png → nobles.png
# Renamed: nobleza.png → nobleza.png
# Renamed: nos (5).png → nos (5).png
# Renamed: nos (6).png → nos (6).png
# Renamed: nos (7).png → nos (7).png
# Renamed: nos (8).png → nos (8).png
# Renamed: nos (9).png → nos (9).png
# Renamed: ofresciendo.png → ofresciendo.png
# Renamed: ofuesen.png → ofuesen.png
# Renamed: ombres.png → ombres.png
# Renamed: on.png → on.png
# Renamed: or.png → or.png
# Renamed: orden.png → orden.png
# Renamed: otros (3).png → otros (3).png
# Renamed: otros (5).png → otros (5).png
# Renamed: otrosi (2).png → otrosi (2).png
# Renamed: otrosi.png → otrosi.png
# Renamed: palabras (2).png → palabras (2).png
# Renamed: para (7).png → para (7).png
# Renamed: para (8).png → para (8).png
# Renamed: para (9).png → para (9).png
# Renamed: participantes.png → participantes.png
# Renamed: paz mas.png → paz mas.png
# Renamed: pecheros y.png → pecheros y.png
# Renamed: peor en.png → peor en.png
# Renamed: pereza.png → pereza.png
# Renamed: peruersa.png → peruersa.png
# Renamed: pluguieron.png → pluguieron.png
# Renamed: po (4).png → po (4).png
# Renamed: po (5).png → po (5).png
# Renamed: po ami.png → po ami.png
# Renamed: po que se.png → po que se.png
# Renamed: pobladas.png → pobladas.png
# Renamed: pobreza.png → pobreza.png
# Renamed: poca (2).png → poca (2).png
# Renamed: poca (3).png → poca (3).png
# Renamed: poca.png → poca.png
# Renamed: poco (4).png → poco (4).png
# Renamed: Poco (7).png → Poco (7).png
# Renamed: podido.png → podido.png
# Renamed: Pompeo (2).png → Pompeo (2).png
# Renamed: pompeo (3).png → pompeo (3).png
# Renamed: pompeo.png → pompeo.png
# Renamed: ponemos.png → ponemos.png
# Renamed: por (25).png → por (25).png
# Renamed: por (26).png → por (26).png
# Renamed: por (27).png → por (27).png
# Renamed: por (28).png → por (28).png
# Renamed: por (29).png → por (29).png
# Renamed: por (30).png → por (30).png
# Renamed: por (31).png → por (31).png
# Renamed: por (32).png → por (32).png
# Renamed: por (33).png → por (33).png
# Renamed: por (34).png → por (34).png
# Renamed: por (35).png → por (35).png
# Renamed: por (36).png → por (36).png
# Renamed: por (37).png → por (37).png
# Renamed: Por (38).png → Por (38).png
# Renamed: Por.png → Por.png
# Renamed: presente.png → presente.png
# Renamed: prevalescia.png → prevalescia.png
# Renamed: primeramente.png → primeramente.png
# Renamed: primero (3).png → primero (3).png
# Renamed: principal.png → principal.png
# Renamed: propria.png → propria.png
# Renamed: publica.png → publica.png
# Renamed: Publio (2).png → Publio (2).png
# Renamed: Publio.png → Publio.png
# Renamed: pudieron.png → pudieron.png
# Renamed: pueblo (3).png → pueblo (3).png
# Renamed: pueblos (2).png → pueblos (2).png
# Renamed: pueden.png → pueden.png
# Renamed: q (2).png → q (2).png
# Renamed: q (3).png → q (3).png
# Renamed: q (4).png → q (4).png
# Renamed: q.png → q.png
# Renamed: qua-.png → qua-.png
# Renamed: qual (7).png → qual (7).png
# Renamed: qual (8).png → qual (8).png
# Renamed: quales (3).png → quales (3).png
# Renamed: quales (4).png → quales (4).png
# Renamed: quales.png → quales.png
# Renamed: que (58).png → que (58).png
# Renamed: que (59).png → que (59).png
# Renamed: que (63).png → que (63).png
# Renamed: que (83) - Copy.png → que (83).png
# Renamed: que (86).png → que (86).png
# Renamed: que (87).png → que (87).png
# Renamed: que (89).png → que (89).png
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 6
#       4 for fname in os.listdir(folder):
#       5     new_name = fname.replace(" - Copy.png", ".png")
# ----> 6     os.rename(os.path.join(folder, fname), os.path.join(folder, new_name))
#       7     print(f"Renamed: {fname} → {new_name}")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data/data_4\\que (91) - Copy.png' -> 'data/data_4\\que (91).png'

# %%
# !pip install docx2pdf PyPDF2
# Out:
# Collecting docx2pdf
#   Downloading docx2pdf-0.1.8-py3-none-any.whl.metadata (3.3 kB)
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pywin32>=227 in c:\users\katej\appdata\roaming\python\python39\site-packages (from docx2pdf) (310)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\katej\appdata\local\programs\python\python39\lib\site-packages (from docx2pdf) (4.65.2)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\katej\appdata\roaming\python\python39\site-packages (from PyPDF2) (4.13.2)
# Requirement already satisfied: colorama in c:\users\katej\appdata\roaming\python\python39\site-packages (from tqdm>=4.41.0->docx2pdf) (0.4.6)
# Downloading docx2pdf-0.1.8-py3-none-any.whl (6.7 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2, docx2pdf
#
#    ---------------------------------------- 0/2 [PyPDF2]
#    ---------------------------------------- 0/2 [PyPDF2]
#    ---------------------------------------- 0/2 [PyPDF2]
#    ---------------------------------------- 0/2 [PyPDF2]
#    ---------------------------------------- 0/2 [PyPDF2]
#    ---------------------------------------- 0/2 [PyPDF2]
#    -------------------- ------------------- 1/2 [docx2pdf]
#    ---------------------------------------- 2/2 [docx2pdf]
#
# Successfully installed PyPDF2-3.0.1 docx2pdf-0.1.8
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from docx2pdf import convert
from PyPDF2 import PdfReader

def docx_to_txt_pages(docx_path, output_dir):
    """
    Converts a .docx to PDF, then extracts each PDF page's text
    and writes it out as page_001.txt, page_002.txt, …
    """
    os.makedirs(output_dir, exist_ok=True)

    # 1) Convert .docx → .pdf (creates same-name .pdf next to .docx)
    pdf_path = os.path.splitext(docx_path)[0] + ".pdf"
    convert(docx_path, pdf_path)

    # 2) Read PDF and dump one .txt per page
    reader = PdfReader(pdf_path)
    for i, page in enumerate(reader.pages, start=1):
        text = page.extract_text() or ""
        txt_name = f"page_{i:03d}.txt"
        with open(os.path.join(output_dir, txt_name), "w", encoding="utf-8") as f:
            f.write(text)

    print(f"Saved {len(reader.pages)} pages → {output_dir}")

if __name__ == "__main__":
    docx_to_txt_pages("data/transcriptions/Borbón_ROTUNDA.docx", "data")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Saved 41 pages → data

# %%
import os
import shutil

def copy_as_foldername(src_root, dst_folder):
    """
    Copy all files from subfolders of src_root into dst_folder.
    Each file is renamed to the folder name it came from.
    Duplicates are numbered as: name.png, name (2).png, name (3).png, ...
    """
    os.makedirs(dst_folder, exist_ok=True)

    for root, dirs, files in os.walk(src_root):
        if root == src_root:
            continue  # skip the root folder itself

        folder_name = os.path.basename(root)
        counter = 1
        for file in files:
            ext = os.path.splitext(file)[1]  # keep original extension
            if counter == 1:
                new_name = f"{folder_name}{ext}"
            else:
                new_name = f"{folder_name} ({counter}){ext}"

            src_path = os.path.join(root, file)
            dst_path = os.path.join(dst_folder, new_name)

            # Ensure no accidental overwrite
            while os.path.exists(dst_path):
                counter += 1
                new_name = f"{folder_name} ({counter}){ext}"
                dst_path = os.path.join(dst_folder, new_name)

            shutil.copy2(src_path, dst_path)
            counter += 1

    print(f"All files copied from '{src_root}' to '{dst_folder}' using folder names only.")

# Example usage:
copy_as_foldername("data/data_6", "data/data_9")
# Out:
# All files copied from 'data/data_6' to 'data/data_9' using folder names only.

# %%
# --- Extract word crops from boxes (no OCR, no labels) ---
# Dependencies: pip install opencv-python numpy pillow (Pillow only if you want PNG compression tweaks)
import re, os
from pathlib import Path
import cv2
import numpy as np

# ==== CONFIG ====
images_dir = Path("data/processed_pages")   # <-- change this
boxes_dir  = Path("data/bounding_boxes")   # <-- change this
out_dir    = Path("data/data_6")  # <-- change this

# Save crops to: out/<page_stem>/0000.png, 0001.png, ...
# Optionally also create a contact sheet per page:
make_contact_sheet = True
contact_sheet_max_width = 2000   # pixels
contact_sheet_gap = 6            # pixels between crops
# Resize each crop so height≈target (helps uniform contact sheets). Set None to keep original sizes.
contact_crop_target_h = 48

# ==== UTILS ====
def parse_numbers(line: str):
    return [float(n) for n in re.findall(r"-?\d+(?:\.\d+)?", line)]

def read_boxes_file(txt_path: Path):
    with open(txt_path, "r", encoding="utf-8", errors="ignore") as f:
        lines = [ln.strip() for ln in f if ln.strip() and not ln.strip().startswith("#")]
    ref_size = None
    boxes = []
    for ln in lines:
        if "img_size" in ln:
            nums = parse_numbers(ln)
            if len(nums) >= 2:
                ref_size = (int(nums[0]), int(nums[1]))  # (W,H)
            continue
        nums = parse_numbers(ln)
        if len(nums) >= 8:
            boxes.append(nums[:8])  # polygon (4 points)
        elif len(nums) >= 4:
            boxes.append(nums[:4])  # rectangle
    return boxes, ref_size

def scale_points(vals, ref_size, img_w, img_h):
    if not ref_size: return vals
    ref_w, ref_h = ref_size
    if ref_w <= 0 or ref_h <= 0: return vals
    sx, sy = img_w / float(ref_w), img_h / float(ref_h)
    return [v * (sx if i % 2 == 0 else sy) for i, v in enumerate(vals)]

def order_polygon(pts: np.ndarray) -> np.ndarray:
    # Order 4 points as tl, tr, br, bl
    rect = np.zeros((4, 2), dtype="float32")
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]  # tl
    rect[2] = pts[np.argmax(s)]  # br
    diff = np.diff(pts, axis=1).reshape(-1)
    rect[1] = pts[np.argmin(diff)]  # tr
    rect[3] = pts[np.argmax(diff)]  # bl
    return rect

def warp_polygon_roi(img: np.ndarray, poly4: np.ndarray) -> np.ndarray:
    rect = order_polygon(poly4.astype("float32"))
    (tl, tr, br, bl) = rect

    # Destination size from edge lengths
    widthA = np.linalg.norm(br - bl)
    widthB = np.linalg.norm(tr - tl)
    maxW = max(1, int(round(max(widthA, widthB))))

    heightA = np.linalg.norm(tr - br)
    heightB = np.linalg.norm(tl - bl)
    maxH = max(1, int(round(max(heightA, heightB))))

    dst = np.array([[0,0],[maxW-1,0],[maxW-1,maxH-1],[0,maxH-1]], dtype="float32")
    M = cv2.getPerspectiveTransform(rect, dst)
    return cv2.warpPerspective(img, M, (maxW, maxH), flags=cv2.INTER_CUBIC)

def crop_xyxy(img: np.ndarray, x1: float, y1: float, x2: float, y2: float) -> np.ndarray:
    h, w = img.shape[:2]
    xa, ya = int(max(0, min(x1, x2))), int(max(0, min(y1, y2)))
    xb, yb = int(min(w, max(x1, x2))), int(min(h, max(y1, y2)))
    if xb <= xa or yb <= ya:
        return np.zeros((1,1), dtype=img.dtype)
    return img[ya:yb, xa:xb]

def infer_xywh_vs_xyxy(vals):
    x1, y1, x2, y2 = vals[:4]
    if x2 >= x1 and y2 >= y1:
        return x1, y1, x2, y2, False  # x1,y1,x2,y2
    return x1, y1, x1 + max(0, x2), y1 + max(0, y2), True  # x,y,w,h

def resize_keep_aspect(img, target_h=None):
    if target_h is None: return img
    h, w = img.shape[:2]
    if h == 0 or w == 0: return img
    scale = target_h / float(h)
    new_w = max(1, int(round(w * scale)))
    return cv2.resize(img, (new_w, target_h), interpolation=cv2.INTER_CUBIC)

def make_contact_sheet_from_crops(crops, max_width=1800, gap=6, bg_color=(255,255,255)):
    # Place variable-width crops row-by-row into a single image
    if not crops:
        return None
    rows = []
    current_row, row_w, row_h = [], 0, 0
    for c in crops:
        h, w = c.shape[:2]
        if row_w + (gap if current_row else 0) + w > max_width and current_row:
            rows.append((current_row, row_w, row_h))
            current_row, row_w, row_h = [], 0, 0
        if current_row:
            row_w += gap
        current_row.append(c)
        row_w += w
        row_h = max(row_h, h)
    if current_row:
        rows.append((current_row, row_w, row_h))

    total_h = sum(rh for _, _, rh in rows) + gap * (len(rows) + 1)
    total_w = max((rw for _, rw, _ in rows), default=0) + gap * 2
    sheet = np.full((total_h, total_w, 3), bg_color, dtype=np.uint8)

    y = gap
    for row_crops, row_w, row_h in rows:
        x = gap
        for c in row_crops:
            h, w = c.shape[:2]
            sheet[y:y+h, x:x+w] = c if c.ndim==3 else cv2.cvtColor(c, cv2.COLOR_GRAY2BGR)
            x += w + gap
        y += row_h + gap
    return sheet

# ==== MAIN ====
out_dir.mkdir(parents=True, exist_ok=True)
image_exts = {".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp"}

for img_path in sorted([p for p in images_dir.iterdir() if p.suffix.lower() in image_exts]):
    page = cv2.imread(str(img_path))
    if page is None:
        print(f"[WARN] Cannot read {img_path}")
        continue

    txt_path = boxes_dir / f"res_{img_path.stem}.txt"
    if not txt_path.exists():
        print(f"[WARN] Missing boxes for {img_path.name} -> {txt_path.name}")
        continue

    boxes, ref_size = read_boxes_file(txt_path)
    H, W = page.shape[:2]
    crops = []
    save_dir = out_dir / img_path.stem
    save_dir.mkdir(parents=True, exist_ok=True)

    for i, vals in enumerate(boxes):
        vals = scale_points(vals, ref_size, W, H)
        if len(vals) >= 8:
            pts = np.array(vals[:8], dtype=np.float32).reshape(4, 2)
            roi = warp_polygon_roi(page, pts)
        else:
            x1, y1, x2, y2, _ = infer_xywh_vs_xyxy(vals[:4])
            roi = crop_xyxy(page, x1, y1, x2, y2)

        # Skip empty/invalid
        if roi.size == 0 or roi.shape[0] < 1 or roi.shape[1] < 1:
            continue

        # Optional normalize: force 3-channel for saving/tiling
        if roi.ndim == 2:
            roi = cv2.cvtColor(roi, cv2.COLOR_GRAY2BGR)

        # Save crop (no labels, simple index)
        out_crop = save_dir / f"{i:04d}.png"
        cv2.imwrite(str(out_crop), roi)

        # For contact sheet (standardize height for nicer packing)
        crops.append(resize_keep_aspect(roi, contact_crop_target_h))

    print(f"[OK] Saved {len(crops)} crops to {save_dir}")

    if make_contact_sheet and crops:
        sheet = make_contact_sheet_from_crops(crops, max_width=contact_sheet_max_width, gap=contact_sheet_gap)
        if sheet is not None:
            cv2.imwrite(str(out_dir / f"{img_path.stem}_contact_sheet.png"), sheet)
            print(f"[OK] Contact sheet: {img_path.stem}_contact_sheet.png")
# Out:
# [OK] Saved 33 crops to data\data_6\page_001
# [OK] Contact sheet: page_001_contact_sheet.png
# [OK] Saved 34 crops to data\data_6\page_002
# [OK] Contact sheet: page_002_contact_sheet.png
# [OK] Saved 33 crops to data\data_6\page_003
# [OK] Contact sheet: page_003_contact_sheet.png
# [OK] Saved 34 crops to data\data_6\page_004
# [OK] Contact sheet: page_004_contact_sheet.png
# [OK] Saved 4 crops to data\data_6\page_005
# [OK] Contact sheet: page_005_contact_sheet.png
